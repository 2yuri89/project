# %% [markdown]
# # 지하철역 소재와 서울시 구/행정동 연결

# %% [markdown]
# ### 1. 데이터 준비

# %%
# 1-1. 필요 라이브러리 불러오기

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point

# 한글 폰트 설정
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
# 1-2. 데이터 파일 불러오기
# 행정동 경계파일 불러오기
dong_gdf = gpd.read_file\
    ('../4.Public_transportation/BND_ADM_DONG_PG_Adong/BND_ADM_DONG_PG.shp',
     encoding='euc-kr')

# 구 경계파일 불러오기
gu_gdf = gpd.read_file\
    ('../4.Public_transportation/LARD_ADM_SECT_SGG_gu/LARD_ADM_SECT_SGG_11_202405.shp',
     encoding='cp949')

# 구별 행정동 목록파일 불러오기
gu_dong_df = pd.read_csv\
    ('../4.Public_transportation/Gu_and_Administrative_dong.csv', encoding='cp949')

# 지하철역 데이터 불러오기
station_df = pd.read_csv\
    ('../4.Public_transportation/subway_latitude_and_longitude.csv', encoding='cp949')

# %% [markdown]
# ### 2. 불러온 데이터 확인

# %%
print("=== 데이터 현황 ===")
print("\n[구 경계 데이터]")
print("- 데이터 크기:", gu_gdf.shape)
print("- 컬럼 목록:", gu_gdf.columns.tolist())
print("- 구 목록:", sorted(gu_gdf['SGG_NM'].tolist()))
print("- 좌표계:", gu_gdf.crs)

print("\n[행정동 경계 데이터]")
print("- 데이터 크기:", dong_gdf.shape)
print("- 컬럼 목록:", dong_gdf.columns.tolist())
print("- 좌표계:", dong_gdf.crs)

print("\n[지하철역 데이터]")
print("- 데이터 크기:", station_df.shape)
print("- 컬럼 목록:", station_df.columns.tolist())
print("- 호선 현황:")
print(station_df['line'].value_counts().sort_index())
# Out:
# === 데이터 현황 ===
#
# [구 경계 데이터]
# - 데이터 크기: (25, 5)
# - 컬럼 목록: ['ADM_SECT_C', 'SGG_NM', 'SGG_OID', 'COL_ADM_SE', 'geometry']
# - 구 목록: ['서울특별시 강남구', '서울특별시 강동구', '서울특별시 강북구', '서울특별시 강서구', '서울특별시 관악구', '서울특별시 광진구', '서울특별시 구로구', '서울특별시 금천구', '서울특별시 노원구', '서울특별시 도봉구', '서울특별시 동대문구', '서울특별시 동작구', '서울특별시 마포구', '서울특별시 서대문구', '서울특별시 서초구', '서울특별시 성동구', '서울특별시 성북구', '서울특별시 송파구', '서울특별시 양천구', '서울특별시 영등포구', '서울특별시 용산구', '서울특별시 은평구', '서울특별시 종로구', '서울특별시 중구', '서울특별시 중랑구']
# - 좌표계: PROJCS["Korea_2000_Korea_Central_Belt_2010",GEOGCS["GCS_Korea_2000",DATUM["Korean_Geodetic_Datum_2002",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6737"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",38],PARAMETER["central_meridian",127],PARAMETER["scale_factor",1],PARAMETER["false_easting",200000],PARAMETER["false_northing",600000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#
# [행정동 경계 데이터]
# - 데이터 크기: (3528, 4)
# - 컬럼 목록: ['BASE_DATE', 'ADM_NM', 'ADM_CD', 'geometry']
# - 좌표계: PROJCS["Korea_2000_Korea_Central_Belt_2010",GEOGCS["GCS_Korea_2000",DATUM["Korean_Geodetic_Datum_2002",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6737"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",38],PARAMETER["central_meridian",127],PARAMETER["scale_factor",1],PARAMETER["false_easting",200000],PARAMETER["false_northing",600000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#
# [지하철역 데이터]
# - 데이터 크기: (788, 5)
# - 컬럼 목록: ['ID', 'name', 'line', 'latitude', 'longitude']
# - 호선 현황:
# line
# 1호선           10
# 2호선           50
# 3호선           34
# 4호선           26
# 5호선           58
# 6호선           39
# 7호선           53
# 7호선(인천)        9
# 8호선           19
# 9호선           25
# 9호선(연장)       13
# 경강선           12
# 경부선           39
# 경원선           33
# 경의중앙선         31
# 경인선           20
# 경춘선           19
# 공항철도1호선       14
# 과천선            9
# 김포골드라인        10
# 별내선            5
# 분당선           35
# 서해선           15
# 수도권 광역급행철도    10
# 수인선           18
# 신림선           11
# 신분당선           6
# 신분당선(연장)       7
# 신분당선(연장2)      3
# 안산선           13
# 에버라인선         15
# 우이신설선         13
# 의정부선          15
# 인천1호선         30
# 인천2호선         27
# 일산선           11
# 장항선            7
# 중앙선           21
# 진접선            3
# Name: count, dtype: int64

# %% [markdown]
# ### 3. 데이터 전처리

# %%
# 3.1 좌표계 통일 (모두 EPSG:4326으로 변환)
dong_gdf = dong_gdf.to_crs("EPSG:4326")
gu_gdf = gu_gdf.to_crs("EPSG:4326")

# 3.2 지하철역 데이터를 GeoDataFrame으로 변환
station_geometry = [Point(xy) for xy in zip(station_df['longitude'], station_df['latitude'])]
station_gdf = gpd.GeoDataFrame(
    station_df, 
    geometry=station_geometry,
    crs="EPSG:4326"
)

print("\n=== 전처리 결과 ===")
print("- 행정동 좌표계:", dong_gdf.crs)
print("- 구 좌표계:", gu_gdf.crs)
print("- 지하철역 좌표계:", station_gdf.crs)
# Out:
# === 전처리 결과 ===
# - 행정동 좌표계: EPSG:4326
# - 구 좌표계: EPSG:4326
# - 지하철역 좌표계: EPSG:4326

# %% [markdown]
# ### 4. 공간 분석 작업

# %%
# 4.1 역과 구 매칭
stations_with_gu = gpd.sjoin(station_gdf, gu_gdf, how='left', predicate='within')

# 4.2 역과 동 매칭
stations_with_dong = gpd.sjoin(station_gdf, dong_gdf, how='left', predicate='within')

# 4.3 최종 데이터프레임 생성
result_df = pd.DataFrame({
    'station_name': stations_with_gu['name'],
    'line': stations_with_gu['line'],
    'gu': stations_with_gu['SGG_NM'],
    'dong': stations_with_dong['ADM_NM']
})

# 4.4 서울시 외 지역 제거
result_df = result_df.dropna(subset=['gu', 'dong'])
result_df = result_df.sort_values(['gu', 'dong', 'line', 'station_name'])
result_df.info()

# 4.5 분석 결과 출력
print(f"서울시 지하철역 수: {len(result_df)}개")

gu_station_count = result_df.groupby('gu').size().sort_values(ascending=False)
print("\n구별 지하철역 수:")
print(gu_station_count)
result_df.head()
result_df['gu'].nunique(), result_df['dong'].nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 407 entries, 638 to 633
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_name  407 non-null    object
#  1   line          407 non-null    object
#  2   gu            407 non-null    object
#  3   dong          407 non-null    object
# dtypes: object(4)
# memory usage: 15.9+ KB
# 서울시 지하철역 수: 407개
#
# 구별 지하철역 수:
# gu
# 서울특별시 강남구     37
# 서울특별시 송파구     30
# 서울특별시 중구      26
# 서울특별시 마포구     24
# 서울특별시 영등포구    23
# 서울특별시 강서구     21
# 서울특별시 서초구     20
# 서울특별시 성동구     19
# 서울특별시 용산구     18
# 서울특별시 동작구     18
# 서울특별시 은평구     16
# 서울특별시 강동구     15
# 서울특별시 종로구     14
# 서울특별시 노원구     14
# 서울특별시 성북구     14
# 서울특별시 중랑구     13
# 서울특별시 구로구     13
# 서울특별시 광진구     11
# 서울특별시 동대문구    11
# 서울특별시 강북구     11
# 서울특별시 관악구     10
# 서울특별시 서대문구     9
# 서울특별시 양천구      8
# 서울특별시 도봉구      8
# 서울특별시 금천구      4
# dtype: int64
# (25, 233)

# %% [markdown]
# ### 5. 서울시 모든 구별 행정동과 매칭

# %%
# 5-1. 최종 데이터프레임 가공
# '서울특별시'와 '구' 이름 분리
result_df['city'] = result_df['gu'].str.split(' ').str[0]
result_df['gu'] = result_df['gu'].str.split(' ').str[1]

# %%
# 5-2. 최종 데이터프레임 컬럼 순서 변경
result_df = result_df[['station_name', 'line', 'city', 'gu', 'dong']]
result_df['gu_dong'] = result_df['gu'] + '_' + result_df['dong']
result_df.head()
# Out:
#     station_name line   city   gu  dong   gu_dong
# 638          개포동  분당선  서울특별시  강남구  개포2동  강남구_개포2동
# 639           구룡  분당선  서울특별시  강남구  개포2동  강남구_개포2동
# 637        대모산입구  분당선  서울특별시  강남구  개포2동  강남구_개포2동
# 699           대청  3호선  서울특별시  강남구  개포3동  강남구_개포3동
# 709           신사  3호선  서울특별시  강남구  논현1동  강남구_논현1동

# %%
# 5-3. gu_dong_df 전처리
# gu_dong_df = gu_dong_df[['gu', 'legal_dong']]
gu_dong_df.columns = ['gu', 'dong']
gu_dong_df['gu_dong'] = gu_dong_df['gu'] + '_' + gu_dong_df['dong']
gu_dong_df = gu_dong_df[['gu', 'dong', 'gu_dong']]

# 5-4. 'gu'와 'dong' 조합으로 고유값 세기
unique_gu_dong_count = gu_dong_df['gu_dong'].drop_duplicates().shape[0]
print(f"구-동 조합의 고유값 개수: {unique_gu_dong_count}")
# Out:
# 구-동 조합의 고유값 개수: 426

# %%
# 5-5. gu_dong_df와 result_df를 dong을 기준으로 left outer join
merged_df = gu_dong_df.merge(result_df, 
                            on='gu_dong', 
                            how='left')
merged_df.info()
# 5-6. station_name과 line이 없는 동은 NaN으로 자동 채워짐
# 필요한 컬럼만 선택하고 정렬
final_df = merged_df[['station_name', 'line', 'gu_x', 'dong_x', 'gu_dong']].sort_values('gu_dong')
final_df.columns = ['station_name', 'line', 'gu', 'dong', 'gu_dong']
final_df.info()

# 5-7. 'gu'와 'dong' 조합으로 고유값 세기
unique_gu_dong_count = final_df['gu_dong'].drop_duplicates().shape[0]
print(f"구-동 조합의 고유값 개수: {unique_gu_dong_count}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gu_x          598 non-null    object
#  1   dong_x        598 non-null    object
#  2   gu_dong       598 non-null    object
#  3   station_name  402 non-null    object
#  4   line          402 non-null    object
#  5   city          402 non-null    object
#  6   gu_y          402 non-null    object
#  7   dong_y        402 non-null    object
# dtypes: object(8)
# memory usage: 37.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 598 entries, 33 to 589
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_name  402 non-null    object
#  1   line          402 non-null    object
#  2   gu            598 non-null    object
#  3   dong          598 non-null    object
#  4   gu_dong       598 non-null    object
# dtypes: object(5)
# memory usage: 28.0+ KB
# 구-동 조합의 고유값 개수: 426

# %% [markdown]
# ### 6. 행정동별 지하철 유무 구분

# %%
# 6-1. 지하철이 있는 행정동
yes_station = result_df
print( yes_station['gu_dong'].nunique() )

# 6-2. 지하철이 없는 행정동
# 빈 데이터프레임 생성 (final_df와 동일한 컬럼을 사용)
no_station = pd.DataFrame(columns=final_df.columns)
# station_name 열이 NaN인 행 필터링
na_rows = final_df[final_df['station_name'].isna()]
# 필터링된 행들을 not_station에 추가
no_station = pd.concat([no_station, na_rows], ignore_index=True)
no_station.info()
print(no_station['gu_dong'].nunique() )
# Out:
# 234
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_name  0 non-null      object
#  1   line          0 non-null      object
#  2   gu            196 non-null    object
#  3   dong          196 non-null    object
#  4   gu_dong       196 non-null    object
# dtypes: object(5)
# memory usage: 7.8+ KB
# 196

# %% [markdown]
# ### 7. 결과 저장

# %%
# 지하철역이 있는 행정동
yes_station.to_csv('수연씨선물/seoul_subway_locations_yes_A.csv', index=False, encoding='cp949')

# 지하철역이 없는 행정동
no_station.to_csv('수연씨선물/seoul_subway_locations_no_A.csv', index=False, encoding='cp949')

# 둘을 종합한 행정동
final_df.to_csv('수연씨선물/seoul_subway_locations_all_A.csv', index=False, encoding='cp949')

# %%
# 상세 위치 정보 출력
print("\n=== 구별 지하철역 상세 목록 ===")
for gu in sorted(result_df['gu'].unique()):
    print(f"\n[{gu}]")
    gu_data = result_df[result_df['gu'] == gu].sort_values(['dong', 'line'])
    for _, row in gu_data.iterrows():
        print(f"- {row['station_name']}({row['line']}): {row['dong']}")
# Out:
# === 구별 지하철역 상세 목록 ===
#
# [강남구]
# - 개포동(분당선): 개포2동
# - 구룡(분당선): 개포2동
# - 대모산입구(분당선): 개포2동
# - 대청(3호선): 개포3동
# - 신사(3호선): 논현1동
# - 논현(7호선): 논현1동
# - 논현(신분당선(연장2)): 논현1동
# - 신사(신분당선(연장2)): 논현1동
# - 강남구청(7호선): 논현2동
# - 학동(7호선): 논현2동
# - 강남구청(분당선): 논현2동
# - 선정릉(분당선): 논현2동
# - 도곡(3호선): 대치1동
# - 삼성(무역센터)(2호선): 대치2동
# - 대치(3호선): 대치2동
# - 학여울(3호선): 대치2동
# - 삼성(수도권 광역급행철도): 대치2동
# - 매봉(3호선): 도곡1동
# - 도곡(분당선): 도곡2동
# - 한티(분당선): 도곡2동
# - 청담(7호선): 삼성1동
# - 봉은사(9호선(연장)): 삼성1동
# - 삼성중앙(9호선(연장)): 삼성2동
# - 선정릉(9호선(연장)): 삼성2동
# - 수서(3호선): 수서동
# - 수서(분당선): 수서동
# - 수서(수도권 광역급행철도): 수서동
# - 압구정(3호선): 압구정동
# - 압구정로데오(분당선): 압구정동
# - 강남(2호선): 역삼1동
# - 선릉(2호선): 역삼1동
# - 역삼(2호선): 역삼1동
# - 신논현(9호선): 역삼1동
# - 언주(9호선(연장)): 역삼1동
# - 선릉(분당선): 역삼1동
# - 신논현(신분당선(연장2)): 역삼1동
# - 일원(3호선): 일원본동
#
# [강동구]
# - 강일(5호선): 강일동
# - 강일(5호선): 강일동
# - 길동(5호선): 길동
# - 둔촌동(5호선): 둔촌1동
# - 둔촌오륜(9호선(연장)): 둔촌1동
# - 중앙보훈병원(9호선(연장)): 둔촌2동
# - 명일(5호선): 명일1동
# - 고덕(5호선): 명일2동
# - 상일동(5호선): 상일1동
# - 강동구청(8호선): 성내1동
# - 강동(5호선): 성내2동
# - 천호(풍납토성)(8호선): 성내2동
# - 암사(8호선): 암사2동
# - 암사역사공원(8호선): 암사3동
# - 굽은다리(강동구민회관앞)(5호선): 천호1동
#
# [강북구]
# - 미아(서울사이버대학)(4호선): 미아동
# - 수유(강북구청)(4호선): 번1동
# - 삼양(우이신설선): 삼양동
# - 삼양사거리(우이신설선): 삼양동
# - 솔샘(우이신설선): 삼양동
# - 미아사거리(4호선): 송천동
# - 화계(우이신설선): 수유1동
# - 가오리(우이신설선): 수유2동
# - 4.19민주묘지(우이신설선): 우이동
# - 북한산우이(우이신설선): 우이동
# - 솔밭공원(우이신설선): 우이동
#
# [강서구]
# - 마곡(5호선): 가양1동
# - 마곡나루(9호선): 가양1동
# - 양천향교(9호선): 가양1동
# - 송정(5호선): 공항동
# - 공항시장(9호선): 공항동
# - 증미(9호선): 등촌1동
# - 가양(9호선): 등촌3동
# - 우장산(5호선): 발산1동
# - 신방화(9호선): 방화1동
# - 마곡나루(공항철도1호선): 방화1동
# - 개화산(5호선): 방화2동
# - 김포공항(5호선): 방화2동
# - 개화(9호선): 방화2동
# - 김포공항(9호선): 방화2동
# - 김포공항(공항철도1호선): 방화2동
# - 김포공항(김포골드라인): 방화2동
# - 김포공항(서해선): 방화2동
# - 방화(5호선): 방화3동
# - 발산(5호선): 우장산동
# - 까치산(5호선): 화곡1동
# - 화곡(5호선): 화곡1동
#
# [관악구]
# - 관악산(서울대)(신림선): 대학동
# - 당곡(신림선): 보라매동
# - 서울대벤처타운(신림선): 서림동
# - 신림(2호선): 서원동
# - 서원(신림선): 서원동
# - 신림(신림선): 신림동
# - 신대방(2호선): 신사동
# - 낙성대(2호선): 인헌동
# - 봉천(2호선): 청룡동
# - 서울대입구(관악구청)(2호선): 청룡동
#
# [광진구]
# - 광나루(장신대)(5호선): 광장동
# - 구의(광진구청)(2호선): 구의1동
# - 아차산(어린이대공원후문)(5호선): 구의2동
# - 강변(동서울터미널)(2호선): 구의3동
# - 군자(능동)(5호선): 능동
# - 군자(능동)(7호선): 능동
# - 어린이대공원(세종대)(7호선): 능동
# - 뚝섬유원지(7호선): 자양4동
# - 중곡(7호선): 중곡3동
# - 건대입구(2호선): 화양동
# - 건대입구(7호선): 화양동
#
# [구로구]
# - 개봉(경인선): 개봉1동
# - 구일(경인선): 구로2동
# - 구로디지털단지(2호선): 구로3동
# - 남구로(7호선): 구로3동
# - 대림(구로구청)(2호선): 구로4동
# - 구로(경부선): 구로5동
# - 온수(성공회대입구)(7호선): 수궁동
# - 온수(성공회대입구)(경인선): 수궁동
# - 도림천(2호선): 신도림동
# - 신도림(2호선): 신도림동
# - 신도림(경부선): 신도림동
# - 오류동(경인선): 오류1동
# - 천왕(7호선): 오류2동
#
# [금천구]
# - 가산디지털단지(7호선): 가산동
# - 가산디지털단지(경부선): 가산동
# - 독산(경부선): 가산동
# - 금천구청(경부선): 시흥1동
#
# [노원구]
# - 태릉입구(6호선): 공릉1동
# - 공릉(서울과학기술대)(7호선): 공릉1동
# - 태릉입구(7호선): 공릉1동
# - 화랑대(서울여대입구)(6호선): 공릉2동
# - 수락산(7호선): 상계1동
# - 노원(4호선): 상계2동
# - 당고개(4호선): 상계3·4동
# - 상계(4호선): 상계5동
# - 노원(7호선): 상계6·7동
# - 마들(7호선): 상계8동
# - 월계(경원선): 월계2동
# - 광운대(경원선): 월계3동
# - 중계(7호선): 중계2·3동
# - 하계(7호선): 하계2동
#
# [도봉구]
# - 도봉산(7호선): 도봉2동
# - 도봉(경원선): 도봉2동
# - 도봉산(경원선): 도봉2동
# - 방학(경원선): 방학1동
# - 쌍문(4호선): 창1동
# - 녹천(경원선): 창1동
# - 창동(경원선): 창4동
# - 창동(4호선): 창5동
#
# [동대문구]
# - 신설동(1호선): 용신동
# - 제기동(1호선): 용신동
# - 신설동(2호선): 용신동
# - 용두(동대문구청)(2호선): 용신동
# - 신설동(우이신설선): 용신동
# - 외대앞(경원선): 이문1동
# - 신이문(경원선): 이문2동
# - 청량리(서울시립대입구)(1호선): 전농1동
# - 청량리(서울시립대입구)(경원선): 전농1동
# - 고려대(종암)(6호선): 제기동
# - 회기(중앙선): 휘경1동
#
# [동작구]
# - 노들(9호선): 노량진1동
# - 노량진(9호선): 노량진1동
# - 노량진(경부선): 노량진1동
# - 보라매(7호선): 대방동
# - 신대방삼거리(7호선): 대방동
# - 사당(2호선): 사당1동
# - 사당(4호선): 사당1동
# - 이수(7호선): 사당1동
# - 동작(현충원)(4호선): 사당2동
# - 총신대입구(이수)(4호선): 사당2동
# - 동작(현충원)(9호선): 사당2동
# - 남성(7호선): 사당4동
# - 상도(7호선): 상도1동
# - 숭실대입구(살피재)(7호선): 상도1동
# - 장승배기(7호선): 상도2동
# - 보라매공원(신림선): 신대방2동
# - 보라매병원(신림선): 신대방2동
# - 흑석(중앙대입구)(9호선): 흑석동
#
# [마포구]
# - 공덕(5호선): 공덕동
# - 공덕(6호선): 공덕동
# - 이대(2호선): 대흥동
# - 대흥(서강대앞)(6호선): 대흥동
# - 서강대(경의중앙선): 대흥동
# - 공덕(경의중앙선): 도화동
# - 공덕(경의중앙선): 도화동
# - 공덕(공항철도1호선): 도화동
# - 디지털미디어시티(6호선): 상암동
# - 디지털미디어시티(공항철도1호선): 상암동
# - 광흥창(서강)(6호선): 서강동
# - 상수(6호선): 서강동
# - 홍대입구(2호선): 서교동
# - 망원(6호선): 서교동
# - 홍대입구(경의중앙선): 서교동
# - 홍대입구(경의중앙선): 서교동
# - 홍대입구(공항철도1호선): 서교동
# - 마포구청(6호선): 성산2동
# - 월드컵경기장(성산)(6호선): 성산2동
# - 아현(2호선): 아현동
# - 애오개(5호선): 아현동
# - 마포(5호선): 용강동
# - 합정(2호선): 합정동
# - 합정(6호선): 합정동
#
# [서대문구]
# - 가좌(경의중앙선): 남가좌1동
# - 신촌(2호선): 신촌동
# - 신촌(경의중앙선): 신촌동
# - 독립문(3호선): 천연동
# - 충정로(경기대입구)(2호선): 충현동
# - 서대문(5호선): 충현동
# - 충정로(경기대입구)(5호선): 충현동
# - 무악재(3호선): 홍제1동
# - 홍제(3호선): 홍제1동
#
# [서초구]
# - 청계산입구(신분당선): 내곡동
# - 반포(7호선): 반포1동
# - 사평(9호선): 반포1동
# - 신반포(9호선): 반포2동
# - 고속터미널(3호선): 반포4동
# - 고속터미널(7호선): 반포4동
# - 고속터미널(9호선): 반포4동
# - 구반포(9호선): 반포본동
# - 내방(7호선): 방배1동
# - 남태령(4호선): 방배2동
# - 방배(2호선): 방배3동
# - 교대(법원.검찰청)(2호선): 서초1동
# - 양재(서초구청)(3호선): 서초2동
# - 강남(신분당선): 서초2동
# - 서초(2호선): 서초3동
# - 교대(법원.검찰청)(3호선): 서초3동
# - 남부터미널(예술의전당)(3호선): 서초3동
# - 양재(서초구청)(신분당선): 양재1동
# - 양재시민의숲(매헌)(신분당선): 양재2동
# - 잠원(3호선): 잠원동
#
# [성동구]
# - 신금호(5호선): 금호1가동
# - 금호(3호선): 금호4가동
# - 마장(5호선): 마장동
# - 용답(2호선): 사근동
# - 한양대(2호선): 사근동
# - 서울숲(분당선): 성수1가1동
# - 뚝섬(2호선): 성수1가2동
# - 성수(2호선): 성수2가3동
# - 옥수(3호선): 옥수동
# - 옥수(경원선): 옥수동
# - 상왕십리(2호선): 왕십리2동
# - 신답(2호선): 용답동
# - 답십리(5호선): 용답동
# - 장한평(5호선): 용답동
# - 응봉(경원선): 응봉동
# - 왕십리(성동구청)(2호선): 행당1동
# - 왕십리(성동구청)(5호선): 행당1동
# - 왕십리(성동구청)(경원선): 행당1동
# - 행당(5호선): 행당2동
#
# [성북구]
# - 길음(4호선): 길음1동
# - 보문(6호선): 보문동
# - 보문(우이신설선): 보문동
# - 성신여대입구(돈암)(4호선): 삼선동
# - 한성대입구(삼선교)(4호선): 삼선동
# - 성신여대입구(돈암)(우이신설선): 삼선동
# - 석계(6호선): 석관동
# - 석계(경원선): 석관동
# - 안암(고대병원앞)(6호선): 안암동
# - 상월곡(한국과학기술연구원)(6호선): 월곡2동
# - 월곡(동덕여대)(6호선): 월곡2동
# - 돌곶이(6호선): 장위2동
# - 정릉(우이신설선): 정릉1동
# - 북한산보국문(우이신설선): 정릉4동
#
# [송파구]
# - 가락시장(3호선): 가락1동
# - 가락시장(8호선): 가락1동
# - 송파(8호선): 가락1동
# - 경찰병원(3호선): 가락2동
# - 개롱(5호선): 가락2동
# - 오금(5호선): 가락본동
# - 거여(5호선): 거여1동
# - 마천(5호선): 마천1동
# - 문정(8호선): 문정2동
# - 복정(8호선): 문정2동
# - 복정(분당선): 문정2동
# - 방이(5호선): 방이1동
# - 송파나루(9호선(연장)): 방이2동
# - 석촌(8호선): 석촌동
# - 석촌(9호선(연장)): 석촌동
# - 석촌고분(9호선(연장)): 석촌동
# - 오금(3호선): 오금동
# - 올림픽공원(한국체대)(5호선): 오륜동
# - 올림픽공원(한국체대)(9호선(연장)): 오륜동
# - 한성백제(9호선(연장)): 오륜동
# - 잠실새내(2호선): 잠실2동
# - 잠실나루(2호선): 잠실4동
# - 몽촌토성(평화의문)(8호선): 잠실4동
# - 잠실(송파구청)(2호선): 잠실6동
# - 잠실(송파구청)(8호선): 잠실6동
# - 종합운동장(2호선): 잠실7동
# - 종합운동장(9호선(연장)): 잠실7동
# - 삼전(9호선(연장)): 잠실본동
# - 장지(8호선): 장지동
# - 천호(풍납토성)(5호선): 풍납1동
#
# [양천구]
# - 목동(5호선): 목1동
# - 오목교(목동운동장앞)(5호선): 목1동
# - 신목동(9호선): 목2동
# - 염창(9호선): 목2동
# - 등촌(9호선): 목3동
# - 신정네거리(2호선): 신정3동
# - 신정(은행정)(5호선): 신정4동
# - 양천구청(2호선): 신정7동
#
# [영등포구]
# - 영등포구청(2호선): 당산1동
# - 영등포구청(5호선): 당산1동
# - 당산(2호선): 당산2동
# - 당산(9호선): 당산2동
# - 대림(구로구청)(7호선): 대림2동
# - 문래(2호선): 문래동
# - 신길(경부선): 신길1동
# - 신풍(7호선): 신길6동
# - 보라매(신림선): 신길6동
# - 대방(경부선): 신길7동
# - 대방(신림선): 신길7동
# - 서울지방병무청(신림선): 신길7동
# - 양평(5호선): 양평1동
# - 선유도(9호선): 양평2동
# - 여의나루(5호선): 여의동
# - 여의도(5호선): 여의동
# - 국회의사당(9호선): 여의동
# - 샛강(9호선): 여의동
# - 여의도(9호선): 여의동
# - 샛강(신림선): 여의동
# - 신길(5호선): 영등포동
# - 영등포시장(5호선): 영등포동
# - 영등포(경부선): 영등포본동
#
# [용산구]
# - 서울역(4호선): 남영동
# - 숙대입구(갈월)(4호선): 남영동
# - 남영(경부선): 남영동
# - 서울역(공항철도1호선): 남영동
# - 서빙고(경원선): 서빙고동
# - 효창공원앞(6호선): 용문동
# - 효창공원앞(경의중앙선): 용문동
# - 녹사평(용산구청)(6호선): 용산2가동
# - 이태원(6호선): 이태원1동
# - 삼각지(4호선): 한강로동
# - 신용산(4호선): 한강로동
# - 이촌(국립중앙박물관)(4호선): 한강로동
# - 삼각지(6호선): 한강로동
# - 용산(경부선): 한강로동
# - 이촌(국립중앙박물관)(경원선): 한강로동
# - 한강진(6호선): 한남동
# - 한남(경원선): 한남동
# - 서울역(경부선): 회현동
#
# [은평구]
# - 구산(6호선): 갈현2동
# - 녹번(3호선): 녹번동
# - 역촌(6호선): 녹번동
# - 불광(3호선): 대조동
# - 불광(6호선): 대조동
# - 연신내(6호선): 대조동
# - 연신내(수도권 광역급행철도): 대조동
# - 독바위(6호선): 불광1동
# - 연신내(3호선): 불광2동
# - 디지털미디어시티(경의중앙선): 수색동
# - 디지털미디어시티(경의중앙선): 수색동
# - 수색(경의중앙선): 수색동
# - 응암(6호선): 신사1동
# - 새절(신사)(6호선): 신사2동
# - 증산(명지대앞)(6호선): 증산동
# - 구파발(3호선): 진관동
#
# [종로구]
# - 경복궁(정부서울청사)(3호선): 사직동
# - 광화문(세종문화회관)(5호선): 사직동
# - 동묘앞(1호선): 숭인1동
# - 혜화(4호선): 이화동
# - 종각(1호선): 종로1·2·3·4가동
# - 종로3가(1호선): 종로1·2·3·4가동
# - 안국(3호선): 종로1·2·3·4가동
# - 종로3가(3호선): 종로1·2·3·4가동
# - 종로3가(5호선): 종로1·2·3·4가동
# - 종로5가(1호선): 종로5·6가동
# - 동대문(4호선): 종로5·6가동
# - 동대문(1호선): 창신1동
# - 동묘앞(6호선): 창신1동
# - 창신(6호선): 창신3동
#
# [중구]
# - 동대문역사문화공원(2호선): 광희동
# - 동대문역사문화공원(4호선): 광희동
# - 동대문역사문화공원(5호선): 광희동
# - 약수(3호선): 다산동
# - 청구(5호선): 다산동
# - 명동(4호선): 명동
# - 시청(1호선): 소공동
# - 시청(2호선): 소공동
# - 을지로입구(2호선): 소공동
# - 신당(2호선): 신당5동
# - 신당(6호선): 신당동
# - 청구(6호선): 신당동
# - 버티고개(6호선): 약수동
# - 약수(6호선): 약수동
# - 을지로3가(2호선): 을지로동
# - 을지로4가(2호선): 을지로동
# - 을지로3가(3호선): 을지로동
# - 을지로4가(5호선): 을지로동
# - 동대입구(3호선): 장충동
# - 충무로(3호선): 필동
# - 충무로(4호선): 필동
# - 서울역(1호선): 회현동
# - 회현(남대문시장)(4호선): 회현동
# - 서울역(경의중앙선): 회현동
# - 서울역(경의중앙선): 회현동
# - 서울(수도권 광역급행철도): 회현동
#
# [중랑구]
# - 신내(6호선): 망우본동
# - 신내(경춘선): 망우본동
# - 양원(중앙선): 망우본동
# - 사가정(7호선): 면목3·8동
# - 용마산(7호선): 면목4동
# - 면목(7호선): 면목본동
# - 먹골(7호선): 묵2동
# - 망우(중앙선): 상봉1동
# - 상봉(시외버스터미널)(중앙선): 상봉1동
# - 상봉(시외버스터미널)(7호선): 상봉2동
# - 봉화산(서울의료원)(6호선): 신내1동
# - 중화(7호선): 중화2동
# - 중랑(중앙선): 중화2동

# %% [markdown]
# ### 8. 구별/동별 수 집계

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 598 entries, 33 to 589
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_name  402 non-null    object
#  1   line          402 non-null    object
#  2   gu            598 non-null    object
#  3   dong          598 non-null    object
#  4   gu_dong       598 non-null    object
# dtypes: object(5)
# memory usage: 28.0+ KB

# %%
gu_dong_df.info()
print(gu_dong_df.to_string())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gu       426 non-null    object
#  1   dong     426 non-null    object
#  2   gu_dong  426 non-null    object
# dtypes: object(3)
# memory usage: 10.1+ KB
#        gu         dong          gu_dong
# 0     강남구          신사동          강남구_신사동
# 1     강남구         논현1동         강남구_논현1동
# 2     강남구         논현2동         강남구_논현2동
# 3     강남구         압구정동         강남구_압구정동
# 4     강남구          청담동          강남구_청담동
# 5     강남구         삼성1동         강남구_삼성1동
# 6     강남구         삼성2동         강남구_삼성2동
# 7     강남구         대치1동         강남구_대치1동
# 8     강남구         대치2동         강남구_대치2동
# 9     강남구         대치4동         강남구_대치4동
# 10    강남구         역삼1동         강남구_역삼1동
# 11    강남구         역삼2동         강남구_역삼2동
# 12    강남구         도곡1동         강남구_도곡1동
# 13    강남구         도곡2동         강남구_도곡2동
# 14    강남구         개포1동         강남구_개포1동
# 15    강남구         개포2동         강남구_개포2동
# 16    강남구         개포3동         강남구_개포3동
# 17    강남구         개포4동         강남구_개포4동
# 18    강남구         일원본동         강남구_일원본동
# 19    강남구         일원1동         강남구_일원1동
# 20    강남구          수서동          강남구_수서동
# 21    강남구          세곡동          강남구_세곡동
# 22    강동구          강일동          강동구_강일동
# 23    강동구         상일1동         강동구_상일1동
# 24    강동구         상일2동         강동구_상일2동
# 25    강동구         명일1동         강동구_명일1동
# 26    강동구         명일2동         강동구_명일2동
# 27    강동구         고덕1동         강동구_고덕1동
# 28    강동구         고덕2동         강동구_고덕2동
# 29    강동구         암사1동         강동구_암사1동
# 30    강동구         암사2동         강동구_암사2동
# 31    강동구         암사3동         강동구_암사3동
# 32    강동구         천호1동         강동구_천호1동
# 33    강동구         천호2동         강동구_천호2동
# 34    강동구         천호3동         강동구_천호3동
# 35    강동구         성내1동         강동구_성내1동
# 36    강동구         성내2동         강동구_성내2동
# 37    강동구         성내3동         강동구_성내3동
# 38    강동구           길동           강동구_길동
# 39    강동구         둔촌1동         강동구_둔촌1동
# 40    강동구         둔촌2동         강동구_둔촌2동
# 41    강북구          삼양동          강북구_삼양동
# 42    강북구          미아동          강북구_미아동
# 43    강북구          송중동          강북구_송중동
# 44    강북구          송천동          강북구_송천동
# 45    강북구         삼각산동         강북구_삼각산동
# 46    강북구          번1동          강북구_번1동
# 47    강북구          번2동          강북구_번2동
# 48    강북구          번3동          강북구_번3동
# 49    강북구         수유1동         강북구_수유1동
# 50    강북구         수유2동         강북구_수유2동
# 51    강북구         수유3동         강북구_수유3동
# 52    강북구          우이동          강북구_우이동
# 53    강북구          인수동          강북구_인수동
# 54    강서구          염창동          강서구_염창동
# 55    강서구         등촌1동         강서구_등촌1동
# 56    강서구         등촌2동         강서구_등촌2동
# 57    강서구         등촌3동         강서구_등촌3동
# 58    강서구         화곡본동         강서구_화곡본동
# 59    강서구         화곡1동         강서구_화곡1동
# 60    강서구         화곡2동         강서구_화곡2동
# 61    강서구         화곡3동         강서구_화곡3동
# 62    강서구         화곡4동         강서구_화곡4동
# 63    강서구         화곡6동         강서구_화곡6동
# 64    강서구         화곡8동         강서구_화곡8동
# 65    강서구         우장산동         강서구_우장산동
# 66    강서구         가양1동         강서구_가양1동
# 67    강서구         가양2동         강서구_가양2동
# 68    강서구         가양3동         강서구_가양3동
# 69    강서구         발산1동         강서구_발산1동
# 70    강서구          공항동          강서구_공항동
# 71    강서구         방화1동         강서구_방화1동
# 72    강서구         방화2동         강서구_방화2동
# 73    강서구         방화3동         강서구_방화3동
# 74    관악구          은천동          관악구_은천동
# 75    관악구          성현동          관악구_성현동
# 76    관악구          청룡동          관악구_청룡동
# 77    관악구          보라매          관악구_보라매
# 78    관악구          청림동          관악구_청림동
# 79    관악구          행운동          관악구_행운동
# 80    관악구         낙성대동         관악구_낙성대동
# 81    관악구          중앙동          관악구_중앙동
# 82    관악구          인헌동          관악구_인헌동
# 83    관악구          남현동          관악구_남현동
# 84    관악구          서원동          관악구_서원동
# 85    관악구          신원동          관악구_신원동
# 86    관악구          서림동          관악구_서림동
# 87    관악구          난곡동          관악구_난곡동
# 88    관악구          신사동          관악구_신사동
# 89    관악구          신림동          관악구_신림동
# 90    관악구          삼성동          관악구_삼성동
# 91    관악구          난향동          관악구_난향동
# 92    관악구          조원동          관악구_조원동
# 93    관악구          대학동          관악구_대학동
# 94    관악구          미성동          관악구_미성동
# 95    광진구         중곡1동         광진구_중곡1동
# 96    광진구         중곡2동         광진구_중곡2동
# 97    광진구         중곡3동         광진구_중곡3동
# 98    광진구         중곡4동         광진구_중곡4동
# 99    광진구           능동           광진구_능동
# 100   광진구         구의1동         광진구_구의1동
# 101   광진구         구의2동         광진구_구의2동
# 102   광진구         구의3동         광진구_구의3동
# 103   광진구          광장동          광진구_광장동
# 104   광진구         자양1동         광진구_자양1동
# 105   광진구         자양2동         광진구_자양2동
# 106   광진구         자양3동         광진구_자양3동
# 107   광진구         자양4동         광진구_자양4동
# 108   광진구          화양동          광진구_화양동
# 109   광진구          군자동          광진구_군자동
# 110   구로구         신도림동         구로구_신도림동
# 111   구로구         구로1동         구로구_구로1동
# 112   구로구         구로2동         구로구_구로2동
# 113   구로구         구로3동         구로구_구로3동
# 114   구로구         구로4동         구로구_구로4동
# 115   구로구         구로5동         구로구_구로5동
# 116   구로구         가리봉동         구로구_가리봉동
# 117   구로구         고척1동         구로구_고척1동
# 118   구로구         고척2동         구로구_고척2동
# 119   구로구         개봉1동         구로구_개봉1동
# 120   구로구         개봉2동         구로구_개봉2동
# 121   구로구         개봉3동         구로구_개봉3동
# 122   구로구         오류1동         구로구_오류1동
# 123   구로구         오류2동         구로구_오류2동
# 124   구로구           항동           구로구_항동
# 125   구로구          수궁동          구로구_수궁동
# 126   금천구          가산동          금천구_가산동
# 127   금천구         독산1동         금천구_독산1동
# 128   금천구         독산2동         금천구_독산2동
# 129   금천구         독산3동         금천구_독산3동
# 130   금천구         독산4동         금천구_독산4동
# 131   금천구         시흥1동         금천구_시흥1동
# 132   금천구         시흥2동         금천구_시흥2동
# 133   금천구         시흥3동         금천구_시흥3동
# 134   금천구         시흥4동         금천구_시흥4동
# 135   금천구         시흥5동         금천구_시흥5동
# 136   노원구         월계1동         노원구_월계1동
# 137   노원구         월계2동         노원구_월계2동
# 138   노원구         월계3동         노원구_월계3동
# 139   노원구         공릉1동         노원구_공릉1동
# 140   노원구         공릉2동         노원구_공릉2동
# 141   노원구         하계1동         노원구_하계1동
# 142   노원구         하계2동         노원구_하계2동
# 143   노원구         중계본동         노원구_중계본동
# 144   노원구         중계1동         노원구_중계1동
# 145   노원구       중계2·3동       노원구_중계2·3동
# 146   노원구         중계4동         노원구_중계4동
# 147   노원구         상계1동         노원구_상계1동
# 148   노원구         상계2동         노원구_상계2동
# 149   노원구       상계3·4동       노원구_상계3·4동
# 150   노원구         상계5동         노원구_상계5동
# 151   노원구       상계6·7동       노원구_상계6·7동
# 152   노원구         상계8동         노원구_상계8동
# 153   노원구         상계9동         노원구_상계9동
# 154   노원구        상계10동        노원구_상계10동
# 155   도봉구         쌍문1동         도봉구_쌍문1동
# 156   도봉구         쌍문2동         도봉구_쌍문2동
# 157   도봉구         쌍문3동         도봉구_쌍문3동
# 158   도봉구         쌍문4동         도봉구_쌍문4동
# 159   도봉구         방학1동         도봉구_방학1동
# 160   도봉구         방학2동         도봉구_방학2동
# 161   도봉구         방학3동         도봉구_방학3동
# 162   도봉구          창1동          도봉구_창1동
# 163   도봉구          창2동          도봉구_창2동
# 164   도봉구          창3동          도봉구_창3동
# 165   도봉구          창4동          도봉구_창4동
# 166   도봉구          창5동          도봉구_창5동
# 167   도봉구         도봉1동         도봉구_도봉1동
# 168   도봉구         도봉2동         도봉구_도봉2동
# 169  동대문구          용신동         동대문구_용신동
# 170  동대문구          제기동         동대문구_제기동
# 171  동대문구         전농1동        동대문구_전농1동
# 172  동대문구         전농2동        동대문구_전농2동
# 173  동대문구        답십리1동       동대문구_답십리1동
# 174  동대문구        답십리2동       동대문구_답십리2동
# 175  동대문구         장안1동        동대문구_장안1동
# 176  동대문구         장안2동        동대문구_장안2동
# 177  동대문구         청량리동        동대문구_청량리동
# 178  동대문구          회기동         동대문구_회기동
# 179  동대문구         휘경1동        동대문구_휘경1동
# 180  동대문구         휘경2동        동대문구_휘경2동
# 181  동대문구         이문1동        동대문구_이문1동
# 182  동대문구         이문2동        동대문구_이문2동
# 183   동작구        노량진1동        동작구_노량진1동
# 184   동작구        노량진2동        동작구_노량진2동
# 185   동작구         상도1동         동작구_상도1동
# 186   동작구         상도2동         동작구_상도2동
# 187   동작구         상도3동         동작구_상도3동
# 188   동작구         상도4동         동작구_상도4동
# 189   동작구          흑석동          동작구_흑석동
# 190   동작구         사당1동         동작구_사당1동
# 191   동작구         사당2동         동작구_사당2동
# 192   동작구         사당3동         동작구_사당3동
# 193   동작구         사당4동         동작구_사당4동
# 194   동작구         사당5동         동작구_사당5동
# 195   동작구          대방동          동작구_대방동
# 196   동작구        신대방1동        동작구_신대방1동
# 197   동작구        신대방2동        동작구_신대방2동
# 198   마포구          아현동          마포구_아현동
# 199   마포구          공덕동          마포구_공덕동
# 200   마포구          도화동          마포구_도화동
# 201   마포구          용강동          마포구_용강동
# 202   마포구          대흥동          마포구_대흥동
# 203   마포구          염리동          마포구_염리동
# 204   마포구          신수동          마포구_신수동
# 205   마포구          서강동          마포구_서강동
# 206   마포구          서교동          마포구_서교동
# 207   마포구          합정동          마포구_합정동
# 208   마포구         망원1동         마포구_망원1동
# 209   마포구         망원2동         마포구_망원2동
# 210   마포구          연남동          마포구_연남동
# 211   마포구         성산1동         마포구_성산1동
# 212   마포구         성산2동         마포구_성산2동
# 213   마포구          상암동          마포구_상암동
# 214  서대문구          충현동         서대문구_충현동
# 215  서대문구          천연동         서대문구_천연동
# 216  서대문구         북아현동        서대문구_북아현동
# 217  서대문구          신촌동         서대문구_신촌동
# 218  서대문구          연희동         서대문구_연희동
# 219  서대문구         홍제1동        서대문구_홍제1동
# 220  서대문구         홍제2동        서대문구_홍제2동
# 221  서대문구         홍제3동        서대문구_홍제3동
# 222  서대문구         홍은1동        서대문구_홍은1동
# 223  서대문구         홍은2동        서대문구_홍은2동
# 224  서대문구        남가좌1동       서대문구_남가좌1동
# 225  서대문구        남가좌2동       서대문구_남가좌2동
# 226  서대문구        북가좌1동       서대문구_북가좌1동
# 227  서대문구        북가좌2동       서대문구_북가좌2동
# 228   서초구         서초1동         서초구_서초1동
# 229   서초구         서초2동         서초구_서초2동
# 230   서초구         서초3동         서초구_서초3동
# 231   서초구         서초4동         서초구_서초4동
# 232   서초구          잠원동          서초구_잠원동
# 233   서초구         반포본동         서초구_반포본동
# 234   서초구         반포1동         서초구_반포1동
# 235   서초구         반포2동         서초구_반포2동
# 236   서초구         반포3동         서초구_반포3동
# 237   서초구         반포4동         서초구_반포4동
# 238   서초구         방배본동         서초구_방배본동
# 239   서초구         방배1동         서초구_방배1동
# 240   서초구         방배2동         서초구_방배2동
# 241   서초구         방배3동         서초구_방배3동
# 242   서초구         방배4동         서초구_방배4동
# 243   서초구         양재1동         서초구_양재1동
# 244   서초구         양재2동         서초구_양재2동
# 245   서초구          내곡동          서초구_내곡동
# 246   성동구        왕십리2동        성동구_왕십리2동
# 247   성동구       왕십리도선동       성동구_왕십리도선동
# 248   성동구          마장동          성동구_마장동
# 249   성동구          사근동          성동구_사근동
# 250   성동구         행당1동         성동구_행당1동
# 251   성동구         행당2동         성동구_행당2동
# 252   성동구          응봉동          성동구_응봉동
# 253   성동구        금호1가동        성동구_금호1가동
# 254   성동구     금호2·3가동      성동구_금호2·3가동
# 255   성동구        금호4가동        성동구_금호4가동
# 256   성동구          옥수동          성동구_옥수동
# 257   성동구       성수1가1동       성동구_성수1가1동
# 258   성동구       성수1가2동       성동구_성수1가2동
# 259   성동구      성수2가1동       성동구_성수2가1동
# 260   성동구       성수2가3동       성동구_성수2가3동
# 261   성동구          송정동          성동구_송정동
# 262   성동구          용답동          성동구_용답동
# 263   성북구          성북동          성북구_성북동
# 264   성북구          삼선동          성북구_삼선동
# 265   성북구          동선동          성북구_동선동
# 266   성북구         돈암1동         성북구_돈암1동
# 267   성북구         돈암2동         성북구_돈암2동
# 268   성북구          안암동          성북구_안암동
# 269   성북구          보문동          성북구_보문동
# 270   성북구         정릉1동         성북구_정릉1동
# 271   성북구         정릉2동         성북구_정릉2동
# 272   성북구         정릉3동         성북구_정릉3동
# 273   성북구         정릉4동         성북구_정릉4동
# 274   성북구         길음1동         성북구_길음1동
# 275   성북구         길음2동         성북구_길음2동
# 276   성북구          종암동          성북구_종암동
# 277   성북구         월곡1동         성북구_월곡1동
# 278   성북구         월곡2동         성북구_월곡2동
# 279   성북구         장위1동         성북구_장위1동
# 280   성북구         장위2동         성북구_장위2동
# 281   성북구         장위3동         성북구_장위3동
# 282   성북구          석관동          성북구_석관동
# 283   송파구         풍납1동         송파구_풍납1동
# 284   송파구         풍납2동         송파구_풍납2동
# 285   송파구         거여1동         송파구_거여1동
# 286   송파구         거여2동         송파구_거여2동
# 287   송파구         마천1동         송파구_마천1동
# 288   송파구         마천2동         송파구_마천2동
# 289   송파구         방이1동         송파구_방이1동
# 290   송파구         방이2동         송파구_방이2동
# 291   송파구          오륜동          송파구_오륜동
# 292   송파구          오금동          송파구_오금동
# 293   송파구         송파1동         송파구_송파1동
# 294   송파구         송파2동         송파구_송파2동
# 295   송파구          석촌동          송파구_석촌동
# 296   송파구          삼전동          송파구_삼전동
# 297   송파구         가락본동         송파구_가락본동
# 298   송파구         가락1동         송파구_가락1동
# 299   송파구         가락2동         송파구_가락2동
# 300   송파구         문정1동         송파구_문정1동
# 301   송파구         문정2동         송파구_문정2동
# 302   송파구          장지동          송파구_장지동
# 303   송파구          위례동          송파구_위례동
# 304   송파구         잠실본동         송파구_잠실본동
# 305   송파구         잠실2동         송파구_잠실2동
# 306   송파구         잠실3동         송파구_잠실3동
# 307   송파구         잠실4동         송파구_잠실4동
# 308   송파구         잠실6동         송파구_잠실6동
# 309   송파구         잠실7동         송파구_잠실7동
# 310   양천구          목1동          양천구_목1동
# 311   양천구          목2동          양천구_목2동
# 312   양천구          목3동          양천구_목3동
# 313   양천구          목4동          양천구_목4동
# 314   양천구          목5동          양천구_목5동
# 315   양천구         신월1동         양천구_신월1동
# 316   양천구         신월2동         양천구_신월2동
# 317   양천구         신월3동         양천구_신월3동
# 318   양천구         신월4동         양천구_신월4동
# 319   양천구         신월5동         양천구_신월5동
# 320   양천구         신월6동         양천구_신월6동
# 321   양천구         신월7동         양천구_신월7동
# 322   양천구         신정1동         양천구_신정1동
# 323   양천구         신정2동         양천구_신정2동
# 324   양천구         신정3동         양천구_신정3동
# 325   양천구         신정4동         양천구_신정4동
# 326   양천구         신정6동         양천구_신정6동
# 327   양천구         신정7동         양천구_신정7동
# 328  영등포구        영등포본동       영등포구_영등포본동
# 329  영등포구         영등포동        영등포구_영등포동
# 330  영등포구          여의동         영등포구_여의동
# 331  영등포구         당산1동        영등포구_당산1동
# 332  영등포구         당산2동        영등포구_당산2동
# 333  영등포구          도림동         영등포구_도림동
# 334  영등포구          문래동         영등포구_문래동
# 335  영등포구         양평1동        영등포구_양평1동
# 336  영등포구         양평2동        영등포구_양평2동
# 337  영등포구         신길1동        영등포구_신길1동
# 338  영등포구         신길3동        영등포구_신길3동
# 339  영등포구         신길4동        영등포구_신길4동
# 340  영등포구         신길5동        영등포구_신길5동
# 341  영등포구         신길6동        영등포구_신길6동
# 342  영등포구         신길7동        영등포구_신길7동
# 343  영등포구         대림1동        영등포구_대림1동
# 344  영등포구         대림2동        영등포구_대림2동
# 345  영등포구         대림3동        영등포구_대림3동
# 346   용산구          후암동          용산구_후암동
# 347   용산구        용산2가동        용산구_용산2가동
# 348   용산구          남영동          용산구_남영동
# 349   용산구          청파동          용산구_청파동
# 350   용산구        원효로1동        용산구_원효로1동
# 351   용산구        원효로2동        용산구_원효로2동
# 352   용산구          효창동          용산구_효창동
# 353   용산구          용문동          용산구_용문동
# 354   용산구         한강로동         용산구_한강로동
# 355   용산구         이촌1동         용산구_이촌1동
# 356   용산구         이촌2동         용산구_이촌2동
# 357   용산구        이태원1동        용산구_이태원1동
# 358   용산구        이태원2동        용산구_이태원2동
# 359   용산구          한남동          용산구_한남동
# 360   용산구         서빙고동         용산구_서빙고동
# 361   용산구          보광동          용산구_보광동
# 362   은평구          녹번동          은평구_녹번동
# 363   은평구         불광1동         은평구_불광1동
# 364   은평구         불광2동         은평구_불광2동
# 365   은평구         갈현1동         은평구_갈현1동
# 366   은평구         갈현2동         은평구_갈현2동
# 367   은평구          구산동          은평구_구산동
# 368   은평구          대조동          은평구_대조동
# 369   은평구         응암1동         은평구_응암1동
# 370   은평구         응암2동         은평구_응암2동
# 371   은평구         응암3동         은평구_응암3동
# 372   은평구          역촌동          은평구_역촌동
# 373   은평구         신사1동         은평구_신사1동
# 374   은평구         신사2동         은평구_신사2동
# 375   은평구          증산동          은평구_증산동
# 376   은평구          수색동          은평구_수색동
# 377   은평구          진관동          은평구_진관동
# 378   종로구       청운효자동        종로구_청운효자동
# 379   종로구          사직동          종로구_사직동
# 380   종로구          삼청동          종로구_삼청동
# 381   종로구          부암동          종로구_부암동
# 382   종로구          평창동          종로구_평창동
# 383   종로구          무악동          종로구_무악동
# 384   종로구          교남동          종로구_교남동
# 385   종로구          가회동          종로구_가회동
# 386   종로구  종로1·2·3·4가동  종로구_종로1·2·3·4가동
# 387   종로구     종로5·6가동      종로구_종로5·6가동
# 388   종로구          이화동          종로구_이화동
# 389   종로구          혜화동          종로구_혜화동
# 390   종로구         창신1동         종로구_창신1동
# 391   종로구         창신2동         종로구_창신2동
# 392   종로구         창신3동         종로구_창신3동
# 393   종로구         숭인1동         종로구_숭인1동
# 394   종로구         숭인2동         종로구_숭인2동
# 395    중구          소공동           중구_소공동
# 396    중구          회현동           중구_회현동
# 397    중구           명동            중구_명동
# 398    중구           필동            중구_필동
# 399    중구          장충동           중구_장충동
# 400    중구          광희동           중구_광희동
# 401    중구         을지로동          중구_을지로동
# 402    중구          신당동           중구_신당동
# 403    중구          다산동           중구_다산동
# 404    중구          약수동           중구_약수동
# 405    중구          청구동           중구_청구동
# 406    중구         신당5동          중구_신당5동
# 407    중구          동화동           중구_동화동
# 408    중구          황학동           중구_황학동
# 409    중구          중림동           중구_중림동
# 410   중랑구         면목본동         중랑구_면목본동
# 411   중랑구         면목2동         중랑구_면목2동
# 412   중랑구      면목3·8동       중랑구_면목3·8동
# 413   중랑구         면목4동         중랑구_면목4동
# 414   중랑구         면목5동         중랑구_면목5동
# 415   중랑구         면목7동         중랑구_면목7동
# 416   중랑구         상봉1동         중랑구_상봉1동
# 417   중랑구         상봉2동         중랑구_상봉2동
# 418   중랑구         중화1동         중랑구_중화1동
# 419   중랑구         중화2동         중랑구_중화2동
# 420   중랑구          묵1동          중랑구_묵1동
# 421   중랑구          묵2동          중랑구_묵2동
# 422   중랑구         망우본동         중랑구_망우본동
# 423   중랑구         망우3동         중랑구_망우3동
# 424   중랑구         신내1동         중랑구_신내1동
# 425   중랑구         신내2동         중랑구_신내2동

# %%
# 8-1. 집계를 위한 Dataframe 만들기
grouped = final_df.groupby(['gu', 'dong', 'gu_dong'])['station_name'].count().reset_index()
grouped.columns = ['gu', 'dong', 'gu_dong', 'station_count']
# 모든 행정동과 병합 (outer join)
all_station_dong = gu_dong_df.merge(grouped, on=['gu', 'dong', 'gu_dong'], how='left')

# 지하철역이 없는 동은 station_count를 0으로 설정
all_station_dong['station_count'] = all_station_dong['station_count'].fillna(0).astype(int)

# 결과 확인
print(all_station_dong)
# Out:
#       gu  dong   gu_dong  station_count
# 0    강남구   신사동   강남구_신사동              0
# 1    강남구  논현1동  강남구_논현1동              4
# 2    강남구  논현2동  강남구_논현2동              4
# 3    강남구  압구정동  강남구_압구정동              2
# 4    강남구   청담동   강남구_청담동              0
# ..   ...   ...       ...            ...
# 421  중랑구   묵2동   중랑구_묵2동              1
# 422  중랑구  망우본동  중랑구_망우본동              3
# 423  중랑구  망우3동  중랑구_망우3동              0
# 424  중랑구  신내1동  중랑구_신내1동              1
# 425  중랑구  신내2동  중랑구_신내2동              0
#
# [426 rows x 4 columns]

# %%
# 8-2. 구별 지하철역 수 집계
# 8-2-1. 모든 구별 지하철역 수
station_gu_all = all_station_dong.groupby('gu')['station_count'].sum().reset_index()
# 8-2-2. 지하철역이 있는 구별 지하철역 수
station_gu_yes = station_gu_all[station_gu_all['station_count'] > 0]
# 8-2-3. 지하철역이 없는 구 목록
station_gu_no = station_gu_all[station_gu_all['station_count'] == 0]

station_gu_all.info(), station_gu_yes.info(), station_gu_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gu             25 non-null     object
#  1   station_count  25 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 428.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gu             25 non-null     object
#  1   station_count  25 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 428.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gu             0 non-null      object
#  1   station_count  0 non-null      int32
# dtypes: int32(1), object(1)
# memory usage: 0.0+ bytes
# (None, None, None)

# %%
# 8-3. 동별 지하철역 수 집계
# 8-3-1. 모든 동별 지하철역 수
station_dong_all = all_station_dong.groupby(['gu', 'dong', 'gu_dong'])['station_count'].sum().reset_index()
# 8-3-2. 지하철역이 있는 동별 지하철역 수
station_dong_yes = station_dong_all[station_dong_all['station_count'] > 0]
# 8-3-3. 지하철역이 없는 동 목록
station_dong_no = station_dong_all[station_dong_all['station_count'] == 0]

station_dong_all.info(), station_dong_yes.info(), station_dong_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gu             426 non-null    object
#  1   dong           426 non-null    object
#  2   gu_dong        426 non-null    object
#  3   station_count  426 non-null    int32
# dtypes: int32(1), object(3)
# memory usage: 11.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 230 entries, 1 to 425
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gu             230 non-null    object
#  1   dong           230 non-null    object
#  2   gu_dong        230 non-null    object
#  3   station_count  230 non-null    int32
# dtypes: int32(1), object(3)
# memory usage: 8.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 196 entries, 0 to 424
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gu             196 non-null    object
#  1   dong           196 non-null    object
#  2   gu_dong        196 non-null    object
#  3   station_count  196 non-null    int32
# dtypes: int32(1), object(3)
# memory usage: 6.9+ KB
# (None, None, None)

# %% [markdown]
# ### 8. 집계 파일 저장

# %%
station_gu_all.to_csv('수연씨선물/4_station_gu_all_Adong.csv', index = False)
station_gu_yes.to_csv('수연씨선물/4_station_gu_yes_Adong.csv', index = False)
station_gu_no.to_csv('수연씨선물/4_station_gu_no_Adong.csv', index = False)
station_dong_all.to_csv('수연씨선물/4_station_dong_all_Adong.csv', index = False)
station_dong_yes.to_csv('수연씨선물/4_station_dong_yes_Adong.csv', index = False)
station_dong_no.to_csv('수연씨선물/4_station_dong_no_Adong.csv', index = False)
