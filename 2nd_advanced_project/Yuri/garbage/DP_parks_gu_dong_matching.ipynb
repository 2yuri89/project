# %% [markdown]
# # 공원과 서울시 구/법정동 연결

# %% [markdown]
# ### 1. 데이터 준비

# %%
# 1-1. 필요 라이브러리 불러오기

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point

# 한글 폰트 설정
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
# 1-2. 데이터 파일 불러오기
# 법정동 경계파일 불러오기
dong_gdf = gpd.read_file\
    ('../4.Public_transportation/LSMD_ADM_SECT_UMD_Ldong/LSMD_ADM_SECT_UMD_11_202409.shp',
     encoding='cp949')

# 구 경계파일 불러오기
gu_gdf = gpd.read_file\
    ('../4.Public_transportation/LARD_ADM_SECT_SGG_gu/LARD_ADM_SECT_SGG_11_202405.shp',
     encoding='cp949')

# 구별 법정동 목록파일 불러오기
gu_dong_df = pd.read_csv\
    ('../4.Public_transportation/Gu_and_Legal_dong.csv', encoding='cp949')

# 공원 데이터 불러오기
park_df = pd.read_csv\
    ('../6.Infrastructure/공원좌표.csv', encoding='cp949')

# %% [markdown]
# ### 2. 불러온 데이터 확인

# %%
print("=== 데이터 현황 ===")
print("\n[구 경계 데이터]")
print("- 데이터 크기:", gu_gdf.shape)
print("- 컬럼 목록:", gu_gdf.columns.tolist())
print("- 구 목록:", sorted(gu_gdf['SGG_NM'].tolist()))
print("- 좌표계:", gu_gdf.crs)

print("\n[법정동 경계 데이터]")
print("- 데이터 크기:", dong_gdf.shape)
print("- 컬럼 목록:", dong_gdf.columns.tolist())
print("- 좌표계:", dong_gdf.crs)

print("\n[공원 데이터]")
print("- 데이터 크기:", park_df.shape)
print("- 컬럼 목록:", park_df.columns.tolist())

print("\n[구별 법정동 데이터]")
print("- 데이터 크기:", gu_dong_df.shape)
print("- 컬럼 목록:", gu_dong_df.columns.tolist())
# Out:
# === 데이터 현황 ===
#
# [구 경계 데이터]
# - 데이터 크기: (25, 5)
# - 컬럼 목록: ['ADM_SECT_C', 'SGG_NM', 'SGG_OID', 'COL_ADM_SE', 'geometry']
# - 구 목록: ['서울특별시 강남구', '서울특별시 강동구', '서울특별시 강북구', '서울특별시 강서구', '서울특별시 관악구', '서울특별시 광진구', '서울특별시 구로구', '서울특별시 금천구', '서울특별시 노원구', '서울특별시 도봉구', '서울특별시 동대문구', '서울특별시 동작구', '서울특별시 마포구', '서울특별시 서대문구', '서울특별시 서초구', '서울특별시 성동구', '서울특별시 성북구', '서울특별시 송파구', '서울특별시 양천구', '서울특별시 영등포구', '서울특별시 용산구', '서울특별시 은평구', '서울특별시 종로구', '서울특별시 중구', '서울특별시 중랑구']
# - 좌표계: PROJCS["Korea_2000_Korea_Central_Belt_2010",GEOGCS["GCS_Korea_2000",DATUM["Korean_Geodetic_Datum_2002",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6737"]],PRIMEM["Greenwich",0],UNIT["Degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",38],PARAMETER["central_meridian",127],PARAMETER["scale_factor",1],PARAMETER["false_easting",200000],PARAMETER["false_northing",600000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#
# [법정동 경계 데이터]
# - 데이터 크기: (467, 5)
# - 컬럼 목록: ['EMD_CD', 'COL_ADM_SE', 'EMD_NM', 'SGG_OID', 'geometry']
# - 좌표계: PROJCS["Korea 2000 / Central Belt 2010",GEOGCS["Korea 2000",DATUM["Geocentric_datum_of_Korea",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],TOWGS84[0,0,0,0,0,0,0],AUTHORITY["EPSG","6737"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433]],PROJECTION["Transverse_Mercator"],PARAMETER["central_meridian",127],PARAMETER["latitude_of_origin",38],PARAMETER["scale_factor",1],PARAMETER["false_easting",200000],PARAMETER["false_northing",600000],UNIT["m",1],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","5186"]]
#
# [공원 데이터]
# - 데이터 크기: (130, 5)
# - 컬럼 목록: ['공원명', 'X좌표(GRS80TM)', 'Y좌표(GRS80TM)', 'X좌표(WGS84)', 'Y좌표(WGS84)']
#
# [구별 법정동 데이터]
# - 데이터 크기: (467, 3)
# - 컬럼 목록: ['ID', 'gu', 'legal_dong']

# %% [markdown]
# ### 3. 데이터 전처리

# %%
# 3-1. 컬럼 정리
# 구_동 데이터 프레임 컬럼 정리
gu_dong_df = gu_dong_df[['gu', 'legal_dong']]
gu_dong_df.columns = ['gu', 'dong']
gu_dong_df['gu_dong'] = gu_dong_df['gu'] + '_' + gu_dong_df['dong']
gu_dong_df.info()
print(gu_dong_df['gu'].nunique())
print(gu_dong_df['dong'].nunique())
print(gu_dong_df['gu_dong'].nunique())

# 3-2. 공원 데이터 프레임 컬럼 정리
park_df.columns = ['park_name', 'X_GRS80TM', 'Y_GRS80TM', 'X_WGS84', 'Y_WGS84']
park_df.dropna()
park_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gu       467 non-null    object
#  1   dong     467 non-null    object
#  2   gu_dong  467 non-null    object
# dtypes: object(3)
# memory usage: 11.1+ KB
# 25
# 465
# 467
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   park_name  130 non-null    object
#  1   X_GRS80TM  119 non-null    float64
#  2   Y_GRS80TM  119 non-null    float64
#  3   X_WGS84    119 non-null    float64
#  4   Y_WGS84    119 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 5.2+ KB

# %%
# 3-3. 좌표계 통일 (모두 EPSG:4326으로 변환)
dong_gdf = dong_gdf.to_crs("EPSG:4326")
gu_gdf = gu_gdf.to_crs("EPSG:4326")

# 3-4. 공원 데이터를 GeoDataFrame으로 변환
park_geometry = [Point(xy) for xy in zip(park_df['X_WGS84'], park_df['Y_WGS84'])]
park_gdf = gpd.GeoDataFrame(
    park_df, 
    geometry=park_geometry,
    crs="EPSG:4326"
)

print("\n=== 전처리 결과 ===")
print("- 법정동 좌표계:", dong_gdf.crs)
print("- 구 좌표계:", gu_gdf.crs)
print("- 공원 좌표계:", park_gdf.crs)
# Out:
# === 전처리 결과 ===
# - 법정동 좌표계: EPSG:4326
# - 구 좌표계: EPSG:4326
# - 공원 좌표계: EPSG:4326

# %% [markdown]
# ### 4. 공간 분석 작업

# %%
# 4.1 공원과 구 매칭
parks_with_gu = gpd.sjoin(park_gdf, gu_gdf, how='left', predicate='intersects')

# 4-1 공원과 동 매칭
parks_with_dong = gpd.sjoin(park_gdf, dong_gdf, how='left', predicate='intersects')

# 4-3 최종 데이터프레임 생성
# 인덱스를 리셋하고 새로운 DataFrame 생성
result_df = pd.DataFrame({
    'park_name': parks_with_dong['park_name'].reset_index(drop=True),
    'gu': parks_with_gu['SGG_NM'],
    'dong': parks_with_dong['EMD_NM'].reset_index(drop=True)
})
result_df.info(), result_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   park_name  130 non-null    object
#  1   gu         113 non-null    object
#  2   dong       112 non-null    object
# dtypes: object(3)
# memory usage: 3.2+ KB
# (None,
#    park_name         gu   dong
#  0      남산공원  서울특별시 용산구  용산동2가
#  1    길동생태공원  서울특별시 강동구     길동
#  2     서울대공원        NaN    NaN
#  3       서울숲  서울특별시 성동구  성수동1가
#  4     월드컵공원  서울특별시 마포구    상암동)

# %%
# 4-5. 동이 NaN인 행 지우기
result_df = result_df.dropna(subset=['dong'])
result_df = result_df.dropna(subset=['park_name'])

result_df.info(), result_df.head(), result_df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112 entries, 0 to 118
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   park_name  112 non-null    object
#  1   gu         112 non-null    object
#  2   dong       112 non-null    object
# dtypes: object(3)
# memory usage: 3.5+ KB
# (None,
#     park_name         gu   dong
#  0       남산공원  서울특별시 용산구  용산동2가
#  1     길동생태공원  서울특별시 강동구     길동
#  3        서울숲  서울특별시 성동구  성수동1가
#  4      월드컵공원  서울특별시 마포구    상암동
#  5  광화문시민열린마당  서울특별시 종로구    세종로,
#  park_name    112
#  gu            24
#  dong          88
#  dtype: int64)

# %%
# # 4-6. '서울특별시'와 '구' 이름 분리
# result_df['city'] = result_df['gu'].str.split(' ').str[0]
# result_df['gu'] = result_df['gu'].str.split(' ').str[1]
# result_df = result_df[['Id', 'park_stop_name', 'gu', 'dong']]
# result_df.nunique()

# 4-7. 특정 열의 모든 공백 제거
result_df['dong'] = result_df['dong'].str.replace(' ', '')
result_df.nunique()
# Out:
# park_name    112
# gu            24
# dong          88
# dtype: int64

# %%
# 4-8. 구별 법정동 목록과 공원 데이터 매칭
result_df = pd.merge(gu_dong_df, result_df, how='outer', on=['dong'])
result_df.nunique(), result_df.info()
result_df = result_df[['park_name', 'gu_x', 'dong', 'gu_dong']]
result_df.columns = ['park_name', 'gu', 'dong', 'gu_dong']
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   gu_x       493 non-null    object
#  1   dong       493 non-null    object
#  2   gu_dong    493 non-null    object
#  3   park_name  116 non-null    object
#  4   gu_y       116 non-null    object
# dtypes: object(5)
# memory usage: 19.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   park_name  116 non-null    object
#  1   gu         493 non-null    object
#  2   dong       493 non-null    object
#  3   gu_dong    493 non-null    object
# dtypes: object(4)
# memory usage: 15.5+ KB

# %%
grouped_df = result_df.groupby('gu_dong')['park_name'].count().reset_index()
# # 출력 제한 해제
# pd.set_option('display.max_rows', None)  # 모든 행 출력
# 출력
print(grouped_df)
# Out:
#      gu_dong  park_name
# 0    강남구_개포동          0
# 1    강남구_논현동          0
# 2    강남구_대치동          0
# 3    강남구_도곡동          1
# 4    강남구_삼성동          1
# ..       ...        ...
# 462  중랑구_면목동          1
# 463   중랑구_묵동          0
# 464  중랑구_상봉동          0
# 465  중랑구_신내동          1
# 466  중랑구_중화동          0
#
# [467 rows x 2 columns]

# %%
# 결과 확인
print("\n최종 데이터 정보:")
print(f"전체 행 수: {len(result_df)}개")
print(f"gu의 NaN 개수: {result_df['gu'].isna().sum()}개")
print(f"dong의 NaN 개수: {result_df['dong'].isna().sum()}개")
result_df.info(), result_df['gu'].nunique(), result_df['dong'].nunique(), \
    result_df['gu_dong'].nunique()
# Out:
# 최종 데이터 정보:
# 전체 행 수: 493개
# gu의 NaN 개수: 0개
# dong의 NaN 개수: 0개
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   park_name  116 non-null    object
#  1   gu         493 non-null    object
#  2   dong       493 non-null    object
#  3   gu_dong    493 non-null    object
# dtypes: object(4)
# memory usage: 15.5+ KB
# (None, 25, 465, 467)

# %% [markdown]
# ### 5. 서울시 모든 구별 법정동과 매칭

# %%
# 6-1. 공원이 있는 법정동
yes_park = result_df
print( yes_park['gu_dong'].nunique() )

# 6-2. 공원이 없는 법정동
# 빈 데이터프레임 생성 (final_df와 동일한 컬럼을 사용)
no_park = pd.DataFrame(columns=result_df.columns)
# park_name 열이 NaN인 행 필터링
na_rows = result_df[result_df['park_name'].isna()]
# 필터링된 행들을 not_park에 추가
no_park = pd.concat([no_park, na_rows], ignore_index=True)
no_park.info()
print(no_park['gu_dong'].nunique() )
print(no_park['gu_dong'].unique() )
# Out:
# 467
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   park_name  0 non-null      object
#  1   gu         377 non-null    object
#  2   dong       377 non-null    object
#  3   gu_dong    377 non-null    object
# dtypes: object(4)
# memory usage: 11.9+ KB
# 377
# ['구로구_가리봉동' '금천구_가산동' '종로구_가회동' '용산구_갈월동' '은평구_갈현동' '강동구_강일동' '강남구_개포동'
#  '강서구_개화동' '송파구_거여동' '종로구_견지동' '종로구_경운동' '종로구_계동' '마포구_공덕동' '노원구_공릉동'
#  '종로구_공평동' '강서구_공항동' '강서구_과해동' '종로구_관수동' '종로구_관철동' '종로구_관훈동' '중구_광희동1가'
#  '중구_광희동2가' '종로구_교남동' '종로구_교북동' '종로구_구기동' '구로구_구로동' '은평구_구산동' '마포구_구수동'
#  '광진구_구의동' '광진구_군자동' '구로구_궁동' '종로구_궁정동' '종로구_권농동' '성동구_금호동2가' '성북구_길음동'
#  '종로구_낙원동' '서대문구_남가좌동' '중구_남대문로1가' '중구_남대문로2가' '중구_남대문로3가' '중구_남대문로4가'
#  '중구_남대문로5가' '중구_남산동1가' '중구_남산동2가' '중구_남산동3가' '용산구_남영동' '중구_남창동' '중구_남학동'
#  '관악구_남현동' '종로구_내수동' '종로구_내자동' '서대문구_냉천동' '마포구_노고산동' '은평구_녹번동' '강남구_논현동'
#  '종로구_누상동' '종로구_누하동' '중구_다동' '영등포구_당산동' '영등포구_당산동1가' '영등포구_당산동2가'
#  '영등포구_당산동3가' '영등포구_당산동4가' '영등포구_당산동5가' '영등포구_당산동6가' '마포구_당인동' '종로구_당주동'
#  '영등포구_대림동' '서대문구_대신동' '은평구_대조동' '강남구_대치동' '서대문구_대현동' '마포구_대흥동' '종로구_도렴동'
#  '영등포구_도림동' '성동구_도선동' '용산구_도원동' '마포구_도화동' '종로구_돈의동' '마포구_동교동' '용산구_동빙고동'
#  '성북구_동선동1가' '성북구_동선동2가' '성북구_동선동3가' '성북구_동선동4가' '성북구_동선동5가' '성북구_동소문동1가'
#  '성북구_동소문동2가' '성북구_동소문동3가' '성북구_동소문동4가' '성북구_동소문동5가' '성북구_동소문동6가'
#  '성북구_동소문동7가' '용산구_동자동' '강동구_둔촌동' '강서구_마곡동' '성동구_마장동' '마포구_마포동' '중구_만리동1가'
#  '마포구_망원동' '중구_명동1가' '중구_명동2가' '종로구_명륜1가' '종로구_명륜2가' '종로구_명륜4가' '종로구_묘동'
#  '중구_무교동' '종로구_무악동' '중구_무학동' '중랑구_묵동' '중구_묵정동' '영등포구_문래동1가' '영등포구_문래동2가'
#  '영등포구_문래동3가' '영등포구_문래동4가' '영등포구_문래동5가' '영등포구_문래동6가' '용산구_문배동' '서대문구_미근동'
#  '강북구_미아동' '서초구_반포동' '서초구_방배동' '중구_방산동' '용산구_보광동' '성북구_보문동1가' '성북구_보문동2가'
#  '성북구_보문동3가' '성북구_보문동4가' '성북구_보문동5가' '성북구_보문동6가' '성북구_보문동7가' '동작구_본동'
#  '중구_봉래동1가' '중구_봉래동2가' '서대문구_봉원동' '종로구_봉익동' '종로구_부암동' '서대문구_북가좌동'
#  '서대문구_북아현동' '중구_북창동' '종로구_사간동' '성동구_사근동' '중구_산림동' '용산구_산천동' '중구_삼각동'
#  '성북구_삼선동1가' '성북구_삼선동2가' '성북구_삼선동3가' '성북구_삼선동4가' '성북구_삼선동5가' '송파구_삼전동'
#  '노원구_상계동' '동작구_상도1동' '동작구_상도동' '중랑구_상봉동' '마포구_상수동' '성동구_상왕십리동' '용산구_서계동'
#  '마포구_서교동' '종로구_서린동' '용산구_서빙고동' '중구_서소문동' '서초구_서초동' '성북구_석관동' '송파구_석촌동'
#  '강동구_성내동' '성북구_성북동1가' '마포구_성산동' '강남구_세곡동' '종로구_소격동' '중구_소공동' '종로구_송월동'
#  '성동구_송정동' '송파구_송파동' '종로구_송현동' '은평구_수색동' '강남구_수서동' '종로구_수송동' '강북구_수유동'
#  '중구_수표동' '중구_수하동' '중구_순화동' '종로구_숭인동' '용산구_신계동' '마포구_신공덕동' '종로구_신교동'
#  '영등포구_신길동' '중구_신당동' '구로구_신도림동' '종로구_신문로1가' '동대문구_신설동' '마포구_신수동' '종로구_신영동'
#  '서초구_신원동' '용산구_신창동' '송파구_신천동' '서대문구_신촌동' '중구_쌍림동' '마포구_아현동' '종로구_안국동'
#  '성북구_안암동1가' '성북구_안암동2가' '성북구_안암동3가' '성북구_안암동4가' '성북구_안암동5가' '강동구_암사동'
#  '강남구_압구정동' '영등포구_양평동' '영등포구_양평동1가' '영등포구_양평동2가' '영등포구_양평동3가' '영등포구_양평동4가'
#  '영등포구_양평동5가' '영등포구_양평동6가' '강남구_역삼동' '은평구_역촌동' '종로구_연건동' '마포구_연남동'
#  '종로구_연지동' '서초구_염곡동' '마포구_염리동' '영등포구_영등포동1가' '영등포구_영등포동3가' '영등포구_영등포동4가'
#  '영등포구_영등포동5가' '영등포구_영등포동6가' '영등포구_영등포동7가' '영등포구_영등포동8가' '서대문구_영천동'
#  '중구_예관동' '중구_예장동' '종로구_예지동' '강서구_오곡동' '강서구_오쇠동' '중구_오장동' '성동구_옥수동'
#  '서대문구_옥천동' '구로구_온수동' '종로구_와룡동' '강서구_외발산동' '마포구_용강동' '성동구_용답동' '용산구_용문동'
#  '용산구_용산동1가' '용산구_용산동3가' '용산구_용산동4가' '용산구_용산동5가' '종로구_운니동' '종로구_원남동'
#  '종로구_원서동' '서초구_원지동' '용산구_원효로1가' '용산구_원효로2가' '용산구_원효로3가' '용산구_원효로4가'
#  '노원구_월계동' '강남구_율현동' '중구_을지로1가' '중구_을지로2가' '중구_을지로3가' '중구_을지로4가'
#  '중구_을지로6가' '중구_을지로7가' '성동구_응봉동' '은평구_응암동' '중구_의주로1가' '중구_의주로2가'
#  '동대문구_이문동' '용산구_이촌동' '용산구_이태원동' '종로구_이화동' '종로구_익선동' '종로구_인사동' '종로구_인의동'
#  '중구_인현동1가' '중구_인현동2가' '중구_입정동' '강남구_자곡동' '광진구_자양동' '서초구_잠원동' '중구_장교동'
#  '종로구_장사동' '동대문구_장안동' '성북구_장위동' '송파구_장지동' '중구_장충동1가' '중구_장충동2가' '종로구_재동'
#  '중구_저동1가' '중구_저동2가' '종로구_적선동' '중구_정동' '동대문구_제기동' '종로구_종로1가' '종로구_종로3가'
#  '종로구_종로4가' '종로구_종로5가' '종로구_종로6가' '성북구_종암동' '중구_주교동' '용산구_주성동' '중구_주자동'
#  '노원구_중계동' '광진구_중곡동' '마포구_중동' '중구_중림동' '종로구_중학동' '중랑구_중화동' '은평구_증산동'
#  '종로구_창성동' '종로구_창신동' '서대문구_창천동' '서대문구_천연동' '구로구_천왕동' '강남구_청담동' '동대문구_청량리동'
#  '용산구_청암동' '종로구_청운동' '종로구_청진동' '용산구_청파동1가' '용산구_청파동2가' '용산구_청파동3가'
#  '종로구_체부동' '중구_초동' '중구_충무로1가' '중구_충무로2가' '중구_충무로3가' '중구_충무로4가' '중구_충무로5가'
#  '종로구_충신동' '중구_충정로1가' '서대문구_충정로2가' '서대문구_충정로3가' '중구_태평로1가' '중구_태평로2가'
#  '마포구_토정동' '종로구_통의동' '종로구_통인동' '종로구_팔판동' '종로구_평동' '종로구_평창동' '송파구_풍납동'
#  '중구_필동1가' '중구_필동2가' '중구_필동3가' '종로구_필운동' '노원구_하계동' '성동구_하왕십리동' '성북구_하월곡동'
#  '마포구_하중동' '용산구_한강로1가' '용산구_한강로2가' '용산구_한강로3가' '용산구_한남동' '서대문구_합동'
#  '성동구_행당동' '종로구_행촌동' '마포구_현석동' '종로구_혜화동' '성동구_홍익동' '서대문구_홍제동' '종로구_홍지동'
#  '종로구_홍파동' '종로구_화동' '광진구_화양동' '중구_황학동' '동대문구_회기동' '중구_회현동1가' '중구_회현동2가'
#  '중구_회현동3가' '종로구_효자동' '종로구_효제동' '용산구_후암동' '종로구_훈정동' '동대문구_휘경동' '동작구_흑석동'
#  '중구_흥인동']

# %%
# 1. 두 데이터프레임의 'gu_dong' 값들을 비교
final_combinations = set(gu_dong_df['gu_dong'].unique())
result_combinations = set(result_df['gu_dong'].unique())

# 2. result_df에는 있지만 final_df에는 없는 조합 확인
diff_combinations = result_combinations - final_combinations
print("result_df에만 있는 구-동 조합 수:", len(diff_combinations))
print("\n차이나는 조합들:")
print(sorted(list(diff_combinations)))

# 3. 원본 데이터 확인
print("\nfinal_df의 gu, dong 컬럼 구조:")
print(result_df[['gu', 'dong']].head())
print("\nresult_df의 gu, dong 컬럼 구조:")
print(result_df[['gu', 'dong']].head())

# 4. 두 데이터프레임의 'gu_dong' 생성 방식 확인
print("\nfinal_df의 gu_dong 생성 방식:")
if 'gu_dong' in result_df.columns:
    print(result_df[['gu', 'dong', 'gu_dong']].head())
# Out:
# result_df에만 있는 구-동 조합 수: 0
#
# 차이나는 조합들:
# []
#
# final_df의 gu, dong 컬럼 구조:
#     gu  dong
# 0  송파구   가락동
# 1  구로구  가리봉동
# 2  금천구   가산동
# 3  강서구   가양동
# 4  강서구   가양동
#
# result_df의 gu, dong 컬럼 구조:
#     gu  dong
# 0  송파구   가락동
# 1  구로구  가리봉동
# 2  금천구   가산동
# 3  강서구   가양동
# 4  강서구   가양동
#
# final_df의 gu_dong 생성 방식:
#     gu  dong   gu_dong
# 0  송파구   가락동   송파구_가락동
# 1  구로구  가리봉동  구로구_가리봉동
# 2  금천구   가산동   금천구_가산동
# 3  강서구   가양동   강서구_가양동
# 4  강서구   가양동   강서구_가양동

# %% [markdown]
# ### 6. 결과 저장

# %%
# 공원이 있는 법정동
yes_park.to_csv('Data_preprocessing/seoul_park_locations_yes.csv', index=False, encoding='cp949')

# 공원이 없는 법정동
no_park.to_csv('Data_preprocessing/seoul_park_locations_no.csv', index=False, encoding='cp949')

# 둘을 종합한 법정동
result_df.to_csv('Data_preprocessing/seoul_park_locations_all.csv', index=False, encoding='cp949')

# %%
# 상세 위치 정보 출력
print("\n=== 구별 공원역 상세 목록 ===")
for gu in sorted(result_df['gu'].unique()):
    print(f"\n[{gu}]")
    gu_data = result_df[result_df['gu'] == gu].sort_values(['dong', 'park_name'])
    for _, row in gu_data.iterrows():
        print(f"- {row['park_name']}: {row['dong']}")
# Out:
# === 구별 공원역 상세 목록 ===
#
# [강남구]
# - nan: 개포동
# - nan: 논현동
# - nan: 대치동
# - 도곡근린공원: 도곡동
# - 봉은공원: 삼성동
# - nan: 세곡동
# - nan: 수서동
# - 도산근린공원: 신사동
# - 신사근린공원: 신사동
# - nan: 압구정동
# - nan: 역삼동
# - nan: 율현동
# - 대모산도시자연공원: 일원동
# - nan: 자곡동
# - nan: 청담동
#
# [강동구]
# - nan: 강일동
# - 동명근린공원: 고덕동
# - 길동생태공원: 길동
# - 일자산근린공원: 길동
# - nan: 둔촌동
# - 샛마을근린공원: 명일동
# - 명일근린공원: 상일동
# - nan: 성내동
# - nan: 암사동
# - 천호근린공원: 천호동
#
# [강북구]
# - nan: 미아동
# - 북서울꿈의숲: 번동
# - 오동근린공원: 번동
# - nan: 수유동
# - 솔밭근린공원: 우이동
#
# [강서구]
# - 궁산근린공원: 가양동
# - 허준공원: 가양동
# - nan: 개화동
# - nan: 공항동
# - nan: 과해동
# - 우장산근린공원: 내발산동
# - 매화근린공원: 등촌동
# - nan: 마곡동
# - 개화근린공원: 방화동
# - 꿩고개근린공원: 방화동
# - 방화근린공원: 방화동
# - 염창근린공원: 염창동
# - nan: 오곡동
# - nan: 오쇠동
# - nan: 외발산동
# - 봉제산공원: 화곡동
#
# [관악구]
# - nan: 남현동
# - 상도근린공원: 봉천동
# - 샘말공원(관악산근린공원 샘말지구): 신림동
#
# [광진구]
# - 아차산공원: 광장동
# - nan: 구의동
# - nan: 군자동
# - 어린이대공원: 능동
# - nan: 자양동
# - nan: 중곡동
# - nan: 화양동
#
# [구로구]
# - nan: 가리봉동
# - 개웅산근린공원: 개봉동
# - 고척근린공원: 고척동
# - nan: 구로동
# - nan: 궁동
# - nan: 신도림동
# - 온수도시자연공원: 오류동
# - nan: 온수동
# - nan: 천왕동
# - 푸른수목원: 항동
#
# [금천구]
# - nan: 가산동
# - 감로천생태공원(관악산): 독산동
# - 금천체육공원(관악산): 독산동
# - 만수천공원(관악산): 독산동
# - 금천폭포근린공원: 시흥동
#
# [노원구]
# - nan: 공릉동
# - nan: 상계동
# - nan: 월계동
# - nan: 중계동
# - nan: 하계동
#
# [도봉구]
# - 서울창포원: 도봉동
# - 발바닥공원: 방학동
# - 쌍문근린공원: 쌍문동
# - 월천근린공원: 창동
# - 초안산근린공원: 창동
# - 초안산생태공원: 창동
#
# [동대문구]
# - 간데메근린공원: 답십리동
# - 답십리근린공원: 답십리동
# - nan: 신설동
# - 용두근린공원: 용두동
# - nan: 이문동
# - nan: 장안동
# - 배봉산근린공원: 전농동
# - nan: 제기동
# - nan: 청량리동
# - nan: 회기동
# - nan: 휘경동
#
# [동작구]
# - 사육신공원: 노량진동
# - 노량진공원: 대방동
# - 국립현충원: 동작동
# - nan: 본동
# - 까치산근린공원: 사당동
# - 삼일근린공원: 사당동
# - nan: 상도1동
# - nan: 상도동
# - 보라매근린공원: 신대방동
# - nan: 흑석동
#
# [마포구]
# - nan: 공덕동
# - nan: 구수동
# - nan: 노고산동
# - nan: 당인동
# - nan: 대흥동
# - nan: 도화동
# - nan: 동교동
# - nan: 마포동
# - nan: 망원동
# - nan: 상수동
# - 상암근린공원: 상암동
# - 월드컵공원: 상암동
# - nan: 서교동
# - nan: 성산동
# - nan: 신공덕동
# - nan: 신수동
# - 갈산근린공원: 신정동
# - 계남근린공원: 신정동
# - nan: 아현동
# - nan: 연남동
# - nan: 염리동
# - nan: 용강동
# - nan: 중동
# - 와우근린공원: 창전동
# - nan: 토정동
# - nan: 하중동
# - 외국인묘지공원: 합정동
# - nan: 현석동
#
# [서대문구]
# - nan: 남가좌동
# - nan: 냉천동
# - nan: 대신동
# - nan: 대현동
# - nan: 미근동
# - nan: 봉원동
# - nan: 북가좌동
# - nan: 북아현동
# - nan: 신촌동
# - 궁동근린공원: 연희동
# - 안산도시자연공원: 연희동
# - nan: 영천동
# - nan: 옥천동
# - nan: 창천동
# - nan: 천연동
# - nan: 충정로2가
# - nan: 충정로3가
# - nan: 합동
# - 독립근린공원: 현저동
# - 백련근린공원: 홍은동
# - nan: 홍제동
#
# [서초구]
# - 인능산도시자연공원: 내곡동
# - nan: 반포동
# - nan: 방배동
# - nan: 서초동
# - nan: 신원동
# - 매헌시민의숲: 양재동
# - 문화예술공원: 양재동
# - nan: 염곡동
# - 우면산도시자연공원: 우면동
# - nan: 원지동
# - nan: 잠원동
#
# [성동구]
# - 응봉공원(대현산배수지공원): 금호동1가
# - nan: 금호동2가
# - 금호근린공원: 금호동3가
# - 달맞이근린공원: 금호동4가
# - nan: 도선동
# - nan: 마장동
# - nan: 사근동
# - nan: 상왕십리동
# - 서울숲: 성수동1가
# - 성수근린공원: 성수동2가
# - nan: 송정동
# - nan: 옥수동
# - nan: 용답동
# - nan: 응봉동
# - nan: 하왕십리동
# - nan: 행당동
# - nan: 홍익동
#
# [성북구]
# - nan: 길음동
# - 개운산근린공원: 돈암동
# - nan: 동선동1가
# - nan: 동선동2가
# - nan: 동선동3가
# - nan: 동선동4가
# - nan: 동선동5가
# - nan: 동소문동1가
# - nan: 동소문동2가
# - nan: 동소문동3가
# - nan: 동소문동4가
# - nan: 동소문동5가
# - nan: 동소문동6가
# - nan: 동소문동7가
# - nan: 보문동1가
# - nan: 보문동2가
# - nan: 보문동3가
# - nan: 보문동4가
# - nan: 보문동5가
# - nan: 보문동6가
# - nan: 보문동7가
# - nan: 삼선동1가
# - nan: 삼선동2가
# - nan: 삼선동3가
# - nan: 삼선동4가
# - nan: 삼선동5가
# - 청량공원: 상월곡동
# - nan: 석관동
# - 성북근린공원: 성북동
# - nan: 성북동1가
# - nan: 안암동1가
# - nan: 안암동2가
# - nan: 안암동3가
# - nan: 안암동4가
# - nan: 안암동5가
# - nan: 장위동
# - 북한산국립공원: 정릉동
# - nan: 종암동
# - nan: 하월곡동
#
# [송파구]
# - 장지근린공원: 가락동
# - nan: 거여동
# - 천마근린공원: 마천동
# - 문정근린공원: 문정동
# - 올림픽공원: 방이동
# - nan: 삼전동
# - nan: 석촌동
# - nan: 송파동
# - nan: 신천동
# - 오금근린공원: 오금동
# - 송파나루근린공원(석촌호수): 잠실동
# - 아시아근린공원: 잠실동
# - nan: 장지동
# - nan: 풍납동
#
# [양천구]
# - 용왕산근린공원: 목동
# - 파리근린공원: 목동
# - 서서울호수공원: 신월동
# - 갈산근린공원: 신정동
# - 계남근린공원: 신정동
#
# [영등포구]
# - nan: 당산동
# - nan: 당산동1가
# - nan: 당산동2가
# - nan: 당산동3가
# - nan: 당산동4가
# - nan: 당산동5가
# - nan: 당산동6가
# - nan: 대림동
# - nan: 도림동
# - nan: 문래동1가
# - nan: 문래동2가
# - nan: 문래동3가
# - nan: 문래동4가
# - nan: 문래동5가
# - nan: 문래동6가
# - nan: 신길동
# - nan: 양평동
# - nan: 양평동1가
# - nan: 양평동2가
# - nan: 양평동3가
# - nan: 양평동4가
# - nan: 양평동5가
# - nan: 양평동6가
# - 선유도근린공원: 양화동
# - 여의도근린공원: 여의도동
# - 자매근린공원: 여의도동
# - 영등포근린공원: 영등포동
# - nan: 영등포동1가
# - 중마루근린공원: 영등포동2가
# - nan: 영등포동3가
# - nan: 영등포동4가
# - nan: 영등포동5가
# - nan: 영등포동6가
# - nan: 영등포동7가
# - nan: 영등포동8가
#
# [용산구]
# - nan: 갈월동
# - nan: 남영동
# - nan: 도원동
# - nan: 동빙고동
# - nan: 동자동
# - nan: 문배동
# - nan: 보광동
# - nan: 산천동
# - nan: 서계동
# - nan: 서빙고동
# - nan: 신계동
# - nan: 신창동
# - nan: 용문동
# - nan: 용산동1가
# - 남산공원: 용산동2가
# - nan: 용산동3가
# - nan: 용산동4가
# - nan: 용산동5가
# - 용산가족공원: 용산동6가
# - nan: 원효로1가
# - nan: 원효로2가
# - nan: 원효로3가
# - nan: 원효로4가
# - nan: 이촌동
# - nan: 이태원동
# - nan: 주성동
# - nan: 청암동
# - nan: 청파동1가
# - nan: 청파동2가
# - nan: 청파동3가
# - nan: 한강로1가
# - nan: 한강로2가
# - nan: 한강로3가
# - nan: 한남동
# - 효창근린공원: 효창동
# - nan: 후암동
#
# [은평구]
# - nan: 갈현동
# - nan: 구산동
# - nan: 녹번동
# - nan: 대조동
# - 불광근린공원: 불광동
# - 향림근린공원: 불광동
# - nan: 수색동
# - 도산근린공원: 신사동
# - 신사근린공원: 신사동
# - nan: 역촌동
# - nan: 응암동
# - nan: 증산동
# - 서오능도시자연공원: 진관동
# - 진관근린공원(구파발폭포): 진관동
#
# [종로구]
# - nan: 가회동
# - nan: 견지동
# - nan: 경운동
# - nan: 계동
# - nan: 공평동
# - nan: 관수동
# - nan: 관철동
# - nan: 관훈동
# - nan: 교남동
# - nan: 교북동
# - nan: 구기동
# - nan: 궁정동
# - nan: 권농동
# - nan: 낙원동
# - nan: 내수동
# - nan: 내자동
# - nan: 누상동
# - nan: 누하동
# - nan: 당주동
# - nan: 도렴동
# - nan: 돈의동
# - 낙산근린공원: 동숭동
# - 마로니에공원: 동숭동
# - nan: 명륜1가
# - nan: 명륜2가
# - 와룡근린공원: 명륜3가
# - nan: 명륜4가
# - nan: 묘동
# - nan: 무악동
# - nan: 봉익동
# - nan: 부암동
# - nan: 사간동
# - 사직근린공원: 사직동
# - 북악산도시자연공원: 삼청동
# - 삼청근린공원: 삼청동
# - nan: 서린동
# - 광화문시민열린마당: 세종로
# - 세종로공원: 세종로
# - nan: 소격동
# - nan: 송월동
# - nan: 송현동
# - nan: 수송동
# - nan: 숭인동
# - nan: 신교동
# - nan: 신문로1가
# - 경희궁: 신문로2가
# - nan: 신영동
# - nan: 안국동
# - nan: 연건동
# - nan: 연지동
# - nan: 예지동
# - 인왕산도시자연공원: 옥인동
# - nan: 와룡동
# - nan: 운니동
# - nan: 원남동
# - nan: 원서동
# - nan: 이화동
# - nan: 익선동
# - nan: 인사동
# - nan: 인의동
# - nan: 장사동
# - nan: 재동
# - nan: 적선동
# - nan: 종로1가
# - 탑골근린공원: 종로2가
# - nan: 종로3가
# - nan: 종로4가
# - nan: 종로5가
# - nan: 종로6가
# - nan: 중학동
# - nan: 창성동
# - nan: 창신동
# - nan: 청운동
# - nan: 청진동
# - nan: 체부동
# - nan: 충신동
# - nan: 통의동
# - nan: 통인동
# - nan: 팔판동
# - nan: 평동
# - nan: 평창동
# - nan: 필운동
# - nan: 행촌동
# - nan: 혜화동
# - nan: 홍지동
# - nan: 홍파동
# - nan: 화동
# - nan: 효자동
# - nan: 효제동
# - nan: 훈정동
#
# [중구]
# - nan: 광희동1가
# - nan: 광희동2가
# - nan: 남대문로1가
# - nan: 남대문로2가
# - nan: 남대문로3가
# - nan: 남대문로4가
# - nan: 남대문로5가
# - nan: 남산동1가
# - nan: 남산동2가
# - nan: 남산동3가
# - nan: 남창동
# - nan: 남학동
# - nan: 다동
# - nan: 만리동1가
# - 손기정체육공원: 만리동2가
# - nan: 명동1가
# - nan: 명동2가
# - nan: 무교동
# - nan: 무학동
# - nan: 묵정동
# - nan: 방산동
# - nan: 봉래동1가
# - nan: 봉래동2가
# - nan: 북창동
# - nan: 산림동
# - nan: 삼각동
# - nan: 서소문동
# - nan: 소공동
# - nan: 수표동
# - nan: 수하동
# - nan: 순화동
# - nan: 신당동
# - nan: 쌍림동
# - nan: 예관동
# - nan: 예장동
# - nan: 오장동
# - nan: 을지로1가
# - nan: 을지로2가
# - nan: 을지로3가
# - nan: 을지로4가
# - 훈련원근린공원: 을지로5가
# - nan: 을지로6가
# - nan: 을지로7가
# - nan: 의주로1가
# - nan: 의주로2가
# - nan: 인현동1가
# - nan: 인현동2가
# - nan: 입정동
# - nan: 장교동
# - nan: 장충동1가
# - nan: 장충동2가
# - nan: 저동1가
# - nan: 저동2가
# - nan: 정동
# - nan: 주교동
# - nan: 주자동
# - nan: 중림동
# - nan: 초동
# - nan: 충무로1가
# - nan: 충무로2가
# - nan: 충무로3가
# - nan: 충무로4가
# - nan: 충무로5가
# - nan: 충정로1가
# - nan: 태평로1가
# - nan: 태평로2가
# - nan: 필동1가
# - nan: 필동2가
# - nan: 필동3가
# - nan: 황학동
# - nan: 회현동1가
# - nan: 회현동2가
# - nan: 회현동3가
# - nan: 흥인동
#
# [중랑구]
# - 중랑캠핑숲: 망우동
# - 용마폭포공원: 면목동
# - nan: 묵동
# - nan: 상봉동
# - 봉화산근린공원: 신내동
# - nan: 중화동

# %% [markdown]
# ### 7. 구별/동별 수 집계

# %%
# 7-1. 집계를 위한 Dataframe 만들기
all_park_dong = result_df.groupby(['gu', 'dong', 'gu_dong'])['park_name'].count().reset_index()
all_park_dong.columns = ['gu', 'dong', 'gu_dong', 'park_count']
all_park_dong
# Out:
#       gu dong  gu_dong  park_count
# 0    강남구  개포동  강남구_개포동           0
# 1    강남구  논현동  강남구_논현동           0
# 2    강남구  대치동  강남구_대치동           0
# 3    강남구  도곡동  강남구_도곡동           1
# 4    강남구  삼성동  강남구_삼성동           1
# ..   ...  ...      ...         ...
# 462  중랑구  면목동  중랑구_면목동           1
# 463  중랑구   묵동   중랑구_묵동           0
# 464  중랑구  상봉동  중랑구_상봉동           0
# 465  중랑구  신내동  중랑구_신내동           1
# 466  중랑구  중화동  중랑구_중화동           0
#
# [467 rows x 4 columns]

# %%
# 7-2. 구별 공원 수 집계
# 7-2-1. 모든 구별 공원 수
park_gu_all = all_park_dong.groupby('gu')['park_count'].sum().reset_index()
# 7-2-2. 공원이 있는 구별 공원 수
park_gu_yes = park_gu_all[park_gu_all['park_count'] > 0]
# 7-2-3. 공원이 없는 구 목록
park_gu_no = park_gu_all[park_gu_all['park_count'] == 0]

park_gu_all.info(), park_gu_yes.info(), park_gu_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gu          25 non-null     object
#  1   park_count  25 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 528.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gu          24 non-null     object
#  1   park_count  24 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 576.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 8 to 8
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gu          1 non-null      object
#  1   park_count  1 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 24.0+ bytes
# (None, None, None)

# %%
# 7-3. 동별 공원 수 집계
# 7-3-1. 모든 동별 공원 수
park_dong_all = all_park_dong.groupby(['gu', 'dong', 'gu_dong'])['park_count'].sum().reset_index()
# 7-3-2. 공원이 있는 동별 공원 수
park_dong_yes = park_dong_all[park_dong_all['park_count'] > 0]
# 7-3-3. 공원이 없는 동 목록
park_dong_no = park_dong_all[park_dong_all['park_count'] == 0]

park_dong_all.info(), park_dong_yes.info(), park_dong_no.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gu          467 non-null    object
#  1   dong        467 non-null    object
#  2   gu_dong     467 non-null    object
#  3   park_count  467 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 14.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 3 to 465
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gu          90 non-null     object
#  1   dong        90 non-null     object
#  2   gu_dong     90 non-null     object
#  3   park_count  90 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 3.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 377 entries, 0 to 466
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gu          377 non-null    object
#  1   dong        377 non-null    object
#  2   gu_dong     377 non-null    object
#  3   park_count  377 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 14.7+ KB
# (None, None, None)

# %% [markdown]
# ### 8. 집계 파일 저장

# %%
park_gu_all.to_csv('Data_Preprocessing/6_park_gu_all.csv', index = False)
park_gu_yes.to_csv('Data_Preprocessing/6_park_gu_yes.csv', index = False)
park_gu_no.to_csv('Data_Preprocessing/6_park_gu_no.csv', index = False)
park_dong_all.to_csv('Data_Preprocessing/6_park_dong_all.csv', index = False)
park_dong_yes.to_csv('Data_Preprocessing/6_park_dong_yes.csv', index = False)
park_dong_no.to_csv('Data_Preprocessing/6_park_dong_no.csv', index = False)
